# %% [markdown]
# # Usando la base de datos sample_mflix, proyecta los datos que se solicitan

# %% [markdown]
# ### Fecha, nombre y texto de cada comentario.

# %%
from pymongo import MongoClient
import pprint
import re
from IPython.display import clear_output

# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb+srv://analytics:analytics-password@testcris.whr7f.mongodb.net/test?authSource=admin&replicaSet=atlas-x3zgu3-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

filter={}
project={
    'date': 1, 
    'name': 1, 
    'text': 1, 
    '_id': 0
}

result = client['sample_mflix']['comments'].find(
  filter=filter,
  projection=project
)

for x in result:
    print('')
    print(x)
# Out:
# ompson', 'text': 'Occaecati dolores facere illum dignissimos nulla. Error at dolorem aspernatur laboriosam voluptate nesciunt placeat. Iusto animi sint facere veritatis accusamus pariatur.', 'date': datetime.datetime(1982, 11, 28, 0, 8, 4)}
#
# {'name': 'Grand Maester Pycelle', 'text': 'Quaerat sed voluptas error asperiores perferendis tempore ab laboriosam. Voluptate iusto tempora aliquam. Rem ad consectetur sed voluptatum repellendus dicta.', 'date': datetime.datetime(1977, 12, 6, 0, 3, 4)}
#
# {'name': 'Lisa Rasmussen', 'text': 'Repellat neque corporis quaerat nulla nesciunt. Doloribus natus facere voluptatibus aliquid sint. At reprehenderit nobis odit eum repellat minus illum similique.', 'date': datetime.datetime(2004, 2, 17, 19, 47, 7)}
#
# {'name': 'Daario Naharis', 'text': 'Provident corrupti nesciunt officiis quidem perspiciatis doloribus eius. Commodi eaque provident quas eius. Voluptas tenetur minima tenetur porro facilis natus repudiandae.', 'date': datetime.datetime(1978, 6, 16, 5, 7, 40)}
#
# {'name': 'Grenn', 'text': 'Sequi sapiente modi ratione. Voluptatem voluptas amet earum et labore ratione. Accusantium ad ipsam fugit eaque quia nulla. Sequi laborum nostrum consectetur officia.', 'date': datetime.datetime(1992, 2, 29, 14, 12, 19)}
#
# {'name': 'Justin Williams', 'text': 'Tempore expedita repellat beatae esse exercitationem. Soluta optio iure impedit facere. Soluta placeat quisquam minima. Esse saepe repellat alias numquam totam nisi repellendus.', 'date': datetime.datetime(1985, 4, 13, 10, 34, 37)}
#
# {'name': 'John Rice', 'text': 'Libero dolores aliquid quibusdam. Deleniti ipsa aliquid optio occaecati officia. Earum facilis quidem aliquam sequi. Eos nemo impedit ipsum est mollitia. Dolor blanditiis omnis ipsam magni.', 'date': datetime.datetime(1979, 1, 5, 22, 6, 46)}
#
# {'name': 'Varys', 'text': 'Nihil suscipit ullam numquam nisi. Reiciendis quo quis facere non.', 'date': datetime.datetime(2017, 7, 29, 2, 42, 16)}
#
# {'name': 'Joshua Kent', 'text': 'Eligendi et inventore perferendis enim culpa dolor. Sit cumque adipisci excepturi doloribus. Ducimus voluptatum vero nulla voluptates.', 'date': datetime.datetime(1999, 8, 11, 23, 17, 31)}
#
# {'name': 'Amy Phillips', 'text': 'Odio dicta minima quas quae praesentium perferendis. Ea labore nesciunt laudantium. Incidunt illum quaerat hic. Explicabo nulla atque sint voluptatibus voluptates rem.', 'date': datetime.datetime(1981, 5, 2, 14, 25, 43)}
#
# {'name': 'Anthony Smith', 'text': 'Aliquam dicta officia iusto accusamus magnam dicta est. Voluptas repellat minus eligendi debitis.\nVeniam pariatur ad error. Modi blanditiis blanditiis fuga omnis. Excepturi veniam quibusdam harum.', 'date': datetime.datetime(1982, 1, 21, 7, 0, 44)}
#
# {'name': 'Meera Reed', 'text': 'Suscipit dolorum perferendis tenetur a voluptatum ut quas voluptatum. Molestias odit vero suscipit quam vitae voluptate. Officia illo maiores harum laborum.', 'date': datetime.datetime(1996, 3, 24, 20, 55, 42)}
#
# {'name': 'Barristan Selmy', 'text': 'Tempora explicabo minima assumenda nobis amet iste ea. Tempora accusamus accusantium tempore. Enim ab cum natus perferendis molestiae esse.', 'date': datetime.datetime(1999, 11, 10, 13, 42, 14)}
#
# {'name': 'Sansa Stark', 'text': 'Numquam placeat consequuntur enim rem reiciendis. Consequatur ipsum esse labore pariatur quasi nostrum. Ab excepturi expedita temporibus blanditiis eligendi iste expedita.', 'date': datetime.datetime(1985, 1, 29, 20, 58, 30)}
#
# {'name': 'Jose Hall', 'text': 'Quod eius odio cumque porro fugiat distinctio veniam. Officiis exercitationem explicabo dolorum aspernatur at eaque architecto.', 'date': datetime.datetime(1977, 2, 9, 12, 35, 51)}
#
# {'name': 'Missandei', 'text': 'Perferendis repudiandae a molestiae ea sed quidem. Impedit perferendis magni cumque perferendis vitae. Mollitia fugiat minus quisquam corrupti. Nulla voluptas debitis eligendi labore illum sit.', 'date': datetime.datetime(1978, 4, 4, 18, 30, 13)}
#
# {'name': 'Emily Ellis', 'text': 'Neque est eligendi et at. Sequi quasi fuga ea dolores impedit. Ratione vitae odio alias sapiente nostrum maxime earum. Quod quia provident quas deleniti pariatur.', 'date': datetime.datetime(2012, 2, 23, 19, 30, 49)}
#
# {'name': 'Donna Russell', 'text': 'Voluptate officiis explicabo labore placeat suscipit. Illo illum aperiam reiciendis quidem nobis aut quidem possimus. Nobis delectus eligendi enim.', 'date': datetime.datetime(1988, 3, 30, 17, 37, 36)}
#
# {'name': 'Yolanda Owen', 'text': 'Ea blanditiis delectus veritatis ipsa deserunt sint. Rem et distinctio totam repellendus temporibus. Ipsa consectetur soluta laborum minus aspernatur.', 'date': datetime.datetime(1993, 3, 28, 5, 6, 55)}
#
# {'name': 'Jason Hernandez', 'text': 'Qui ipsum nulla dolore aut neque fugiat iste. Voluptate reiciendis aspernatur temporibus nesciunt illo expedita quia. Distinctio soluta cupiditate reiciendis at quam vel id.', 'date': datetime.datetime(1977, 9, 23, 8, 36, 48)}
#
# {'name': 'Joffrey Baratheon', 'text': 'Tempora totam neque facere sit porro hic quas aliquid. Occaecati saepe vero iusto voluptates magnam repellat.', 'date': datetime.datetime(2015, 12, 15, 3, 56, 8)}
#
# {'name': 'Megan Turner', 'text': 'Veniam corporis repellat unde voluptates sed. Deserunt hic explicabo aspernatur similique aut.', 'date': datetime.datetime(1974, 5, 7, 15, 29, 11)}
#
# {'name': 'Greg Powell', 'text': 'Perspiciatis ex fugiat tempore occaecati reiciendis voluptatem animi. Vel explicabo sed pariatur atque nemo. Aspernatur tempora assumenda ab perspiciatis voluptatum.', 'date': datetime.datetime(1989, 6, 19, 21, 14, 13)}
#
# {'name': 'Lancel Lannister', 'text': 'Autem ipsam iusto reiciendis ipsa. Officiis saepe asperiores consequuntur ipsam inventore sed tenetur. Molestiae magnam tempora error et. Fuga asperiores quas accusantium sint maxime delectus.', 'date': datetime.datetime(2002, 2, 21, 8, 54, 44)}
#
# {'name': 'Phillip Collins', 'text': 'Rerum nesciunt provident quasi. Enim nihil quo quo totam. Adipisci in quo deleniti amet facilis quasi vitae.', 'date': datetime.datetime(1972, 11, 4, 16, 58, 38)}
#
# {'name': 'Ellaria Sand', 'text': 'Excepturi at adipisci animi consequatur est. Voluptate aspernatur voluptatem distinctio nemo quod ipsam. Fuga voluptatem corrupti vitae officiis.', 'date': datetime.datetime(1985, 8, 9, 21, 59, 57)}
#
# {'name': 'Yolanda Owen', 'text': 'Illo minus repellendus labore aut deserunt ipsa numquam. Aperiam veniam inventore est praesentium consectetur. Nemo dolor eligendi nemo earum.', 'date': datetime.datetime(1983, 3, 9, 20, 33, 11)}
#
# {'name': 'Connie Johnson', 'text': 'Iusto nemo similique labore non. Esse quos ullam sapiente corrupti. Consectetur odit repellendus dignissimos voluptas repudiandae omnis odit. Natus commodi eos reprehenderit cupiditate temporibus.', 'date': datetime.datetime(2011, 1, 23, 2, 33, 23)}
#
# {'name': 'Lancel Lannister', 'text': 'Soluta sunt impedit rerum esse. Officia praesentium dolores architecto dolor est. Neque accusamus cum aspernatur laborum ex enim facilis beatae. Mollitia eaque debitis nobis optio natus.', 'date': datetime.datetime(2003, 8, 6, 14, 25, 35)}
#
# {'name': 'Lancel Lannister', 'text': 'Ullam nulla eos consequatur minus distinctio dolor architecto. Autem quas reprehenderit dolorem ea.', 'date': datetime.datetime(2011, 7, 14, 8, 53, 7)}
#
# {'name': 'Ashlee Hart', 'text': 'Perferendis fugiat error similique eligendi ipsum. Harum placeat sed voluptatem aperiam repellendus. Minima natus consequatur aut quidem fuga quam numquam.', 'date': datetime.datetime(2015, 6, 25, 15, 32, 23)}
#
# {'name': 'Catelyn Stark', 'text': 'Voluptatibus repellat nisi ut excepturi. Dolor tenetur in vero quidem iure. In aut eveniet ratione tempora asperiores sunt. Officiis eveniet porro at vel eos.', 'date': datetime.datetime(1994, 4, 3, 10, 7, 5)}
#
# {'name': 'Beric Dondarrion', 'text': 'Quaerat neque doloremque ipsam tempora provident labore nihil. Voluptatum laudantium accusamus provident. Asperiores ex cumque nam est.', 'date': datetime.datetime(2007, 4, 2, 12, 18, 14)}
#
# {'name': 'Thomas Green', 'text': 'Libero dicta repellat autem. Hic suscipit ipsam et. Cupiditate quis vero sit laboriosam.', 'date': datetime.datetime(1989, 5, 26, 23, 44, 35)}
#
# {'name': 'Myrcella Baratheon', 'text': 'Labore impedit eveniet provident incidunt nesciunt. Dignissimos eum nemo possimus occaecati.', 'date': datetime.datetime(1991, 12, 9, 19, 24, 7)}
#
# {'name': 'Yvette Roth', 'text': 'Cum inventore eligendi accusantium adipisci architecto. Quos amet voluptate impedit assumenda recusandae magni.', 'date': datetime.datetime(2017, 1, 23, 14, 3, 45)}
#
# {'name': 'Lori Franklin', 'text': 'Totam odit ipsa non quae asperiores perspiciatis atque tempora. Magni saepe culpa commodi necessitatibus pariatur eaque. Quis odit amet consectetur cumque recusandae.', 'date': datetime.datetime(1983, 6, 5, 10, 27, 12)}
#
# {'name': 'Talisa Maegyr', 'text': 'Consectetur unde eaque voluptates pariatur laudantium. Odit provident exercitationem ab veritatis quae. Minus cumque amet harum quidem numquam dolorum.', 'date': datetime.datetime(2003, 5, 23, 18, 54, 33)}
#
# {'name': 'Jeor Mormont', 'text': 'Quae esse iste error. Minima veritatis nesciunt inventore eaque libero sapiente tenetur. Vitae cumque perspiciatis nobis deserunt distinctio.', 'date': datetime.datetime(2014, 5, 18, 0, 4, 30)}
#
# {'name': 'Tommen Baratheon', 'text': 'Explicabo nobis corrupti et doloribus ipsum. Reprehenderit ipsam culpa vero fugiat dolore porro rem.', 'date': datetime.datetime(1972, 1, 10, 11, 44, 20)}
#
# {'name': 'Morgan Smith', 'text': 'Natus libero rerum molestiae cupiditate. Explicabo dolor itaque nostrum quia animi ipsa.', 'date': datetime.datetime(1993, 2, 21, 11, 12, 6)}
#
# {'name': 'Olly', 'text': 'Facere nobis saepe neque facilis debitis. Provident alias delectus commodi repudiandae ab velit aliquam. Sed animi voluptatibus natus ullam. Possimus quaerat voluptas reprehenderit magni.', 'date': datetime.datetime(2004, 7, 22, 13, 17, 28)}
#
# {'name': 'Meryn Trant', 'text': 'Eligendi doloribus nostrum sapiente. Esse temporibus quas in quidem. Vero saepe illum quod sapiente quisquam. Eum sunt modi quod id.', 'date': datetime.datetime(1971, 10, 28, 16, 28, 45)}
#
# {'name': 'Sansa Stark', 'text': 'Labore numquam impedit doloremque quibusdam in possimus beatae. Veniam explicabo dolores magnam libero. Necessitatibus soluta provident temporibus sed dicta nemo saepe.', 'date': datetime.datetime(1999, 4, 12, 9, 20, 15)}
#
# {'name': 'Nicholas Johnson', 'text': 'Fugiat omnis debitis necessitatibus dolore consectetur. Quos ad deserunt tenetur dolore vitae. Quasi vel eaque placeat necessitatibus alias quidem voluptate. Mollitia odio perspiciatis eaque dolores.', 'date': datetime.datetime(1994, 5, 6, 7, 10, 59)}
#
# {'name': 'Jojen Reed', 'text': 'Sequi reprehenderit suscipit eveniet quod sint aut. Quas suscipit suscipit eaque expedita dolorum vitae temporibus. Vitae occaecati itaque autem fuga sapiente odio.', 'date': datetime.datetime(2014, 4, 2, 15, 55, 35)}
#
# {'name': 'Victoria Sanders', 'text': 'Vero suscipit omnis pariatur omnis tenetur ut facilis. Dolores nobis cum iure dolores esse nisi ad. Ratione atque consequuntur quia dicta.', 'date': datetime.datetime(1989, 5, 5, 18, 58, 54)}
#
# {'name': 'foo bar', 'text': 'test comment', 'date': datetime.datetime(2018, 3, 27, 13, 0, 50, 332000)}
#
# {'name': 'gaixjzunk', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 27, 25, 998000)}
#
# {'name': 'oi2ilgkk9', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 29, 2, 961000)}
#
# {'name': 'isbhi4ow5', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 30, 8, 151000)}
#
# {'name': 'fnwbi77bl', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 31, 37, 527000)}
#
# {'name': '0xlhaxf6r', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 34, 48, 693000)}
#
# {'name': 't0rmstg6h', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 37, 38, 945000)}
#
# {'name': 'egrkfzdna', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 40, 35, 193000)}
#
# {'name': 'hswdc8zuo', 'text': 'feefee', 'date': datetime.datetime(2018, 3, 27, 14, 41, 24, 173000)}
#
# {'name': 'j8pza1w27', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 2, 12, 2, 50, 596000)}
#
# {'name': 'ounj9rsxa', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 2, 12, 33, 5, 601000)}
#
# {'name': 'upoitg3sa', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 2, 12, 37, 15, 432000)}
#
# {'name': 'h7uqitc9k', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 4, 9, 40, 33, 348000)}
#
# {'name': '1dls8ko0o', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 4, 15, 56, 29, 13000)}
#
# {'name': 'ubjfpg48b', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 5, 10, 51, 58, 46000)}
#
# {'name': 'mhl9p4y5d', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 5, 10, 52, 28, 205000)}
#
# {'name': 'tlztq1ul4', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 5, 10, 53, 41, 623000)}
#
# {'name': 'r60ef30hv', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 5, 10, 59, 55, 493000)}
#
# {'name': 'x5ntbqhup', 'text': 'feefee', 'date': datetime.datetime(2018, 4, 6, 16, 37, 3, 422000)}
#
# {'name': 'jfl2zwnlw', 'text': 'feefee', 'date': datetime.datetime(2018, 4, 6, 16, 39, 8, 721000)}
#
# {'name': '0ye0peyb2', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 9, 10, 29, 4, 287000)}
#
# {'name': 'ck6xqw9tt', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 9, 21, 23, 11, 363000)}
#
# {'name': 'oxa632ezc', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 8, 24, 10, 197000)}
#
# {'name': 'f0yvm7m0v', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 22, 15, 400000)}
#
# {'name': '591qprbvu', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 23, 4, 396000)}
#
# {'name': 'debq9wl8f', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 38, 45, 638000)}
#
# {'name': '8zhqu2a39', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 39, 30, 709000)}
#
# {'name': 'fqjgs1poq', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 47, 32, 212000)}
#
# {'name': 'uzxftvo08', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 48, 50, 779000)}
#
# {'name': 'f8skywjq8', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 10, 9, 49, 36, 982000)}
#
# {'name': 'sw6jy3ay4', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 16, 15, 8, 25, 199000)}
#
# {'name': 'rym6g9xkw', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 16, 15, 12, 48, 195000)}
#
# {'name': 'jalfsirll', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 16, 15, 13, 8, 909000)}
#
# {'name': 'k33kh2nek', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 20, 10, 14, 25, 795000)}
#
# {'name': 'uljakglqr', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 20, 10, 18, 41, 11000)}
#
# {'name': 'ly65w5o7n', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 20, 10, 49, 10, 396000)}
#
# {'name': 'kpdm85qy1', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 23, 10, 36, 29, 354000)}
#
# {'name': 'bu9i2w0xi', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 23, 10, 40, 28, 903000)}
#
# {'name': '1zzyymlks', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 23, 11, 27, 49, 334000)}
#
# {'name': '9axvm057f', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 4, 23, 11, 30, 35, 578000)}
#
# {'name': 'vzgg2p0ff', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 5, 2, 8, 55, 4, 754000)}
#
# {'name': '9lk9r112i', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 5, 2, 9, 4, 7, 703000)}
#
# {'name': 'j9g70tily', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 5, 2, 9, 6, 15, 678000)}
#
# {'name': '6vxrmk989', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 5, 29, 15, 41, 6, 726000)}
#
# {'name': 'p761mca88', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 5, 29, 15, 43, 14, 65000)}
#
# {'name': '3vymtwvq9', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 6, 29, 17, 14, 52, 324000)}
#
# {'name': '51wx8q6ah', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 9, 54, 21, 594000)}
#
# {'name': 'gxq1e30n2', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 9, 58, 28, 47000)}
#
# {'name': '26ogav96w', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 9, 58, 56, 932000)}
#
# {'name': 't96pp7wji', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 10, 4, 17, 174000)}
#
# {'name': 'cuhpee645', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 10, 4, 51, 578000)}
#
# {'name': 'c0o9yac4o', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 10, 6, 22, 485000)}
#
# {'name': 'hlizb0jjt', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 10, 6, 49, 661000)}
#
# {'name': '261529awx', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 10, 7, 37, 109000)}
#
# {'name': 't3b656anv', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 1, 10, 11, 20, 112000)}
#
# {'name': 'bbw6dadfe', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 13, 40, 29, 394000)}
#
# {'name': 'ztcviee3w', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 14, 4, 57, 526000)}
#
# {'name': 'y5uve0uql', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 2, 12, 67000)}
#
# {'name': 'z49ahxnxe', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 4, 28, 72000)}
#
# {'name': 'e5ghwc58r', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 6, 36, 772000)}
#
# {'name': 'kovdob65w', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 8, 10, 715000)}
#
# {'name': 'iukovzpo8', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 11, 47, 125000)}
#
# {'name': 'ndr4563es', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 14, 7, 924000)}
#
# {'name': 'x79ado7jj', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 13, 20, 21, 37, 783000)}
#
# {'name': 'foobar', 'text': 'frobscottle', 'date': datetime.datetime(2018, 8, 13, 20, 25, 34, 174000)}
#
# {'name': 'foobar', 'text': 'fe-fi-fo-fum', 'date': datetime.datetime(2018, 8, 13, 20, 28, 22, 651000)}
#
# {'name': 'foobar', 'text': 'fe-fi-fo-fum', 'date': datetime.datetime(2018, 8, 13, 20, 28, 37, 711000)}
#
# {'name': 'foobar', 'text': 'fe-fi-fo-fum', 'date': datetime.datetime(2018, 8, 13, 20, 29, 36, 938000)}
#
# {'name': 'xw3rnviyk', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 11, 49, 50, 688000)}
#
# {'name': 'tina71wss', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 12, 49, 3, 337000)}
#
# {'name': 'pj4hemog2', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 12, 54, 44, 412000)}
#
# {'name': 'fqlgxyhy4', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 12, 56, 16, 391000)}
#
# {'name': 'jol9d6ze3', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 13, 5, 54, 636000)}
#
# {'name': 'b1k7xex8r', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 13, 9, 0, 120000)}
#
# {'name': 'gwy1uyx6i', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 13, 17, 29, 958000)}
#
# {'name': '7ny89nwrm', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 13, 25, 0, 622000)}
#
# {'name': 'gwog3g40h', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 14, 9, 26, 546000)}
#
# {'name': 'otagytcbw', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 14, 12, 44, 608000)}
#
# {'name': 'tm7gih7w8', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 14, 40, 35, 400000)}
#
# {'name': 'g7pnd0yy2', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 14, 53, 11, 550000)}
#
# {'name': 'sg1u6swo4', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 15, 0, 25, 211000)}
#
# {'name': 'yznjm1yul', 'text': 'feefee', 'date': datetime.datetime(2018, 8, 14, 15, 1, 16, 716000)}
#
# {'name': 'jjjdmntww', 'text': 'feefee', 'date': datetime.datetime(2018, 8, 14, 15, 3, 14, 306000)}
#
# {'name': 'sxkybvzb6', 'text': 'fazzlebizzle', 'date': datetime.datetime(2018, 8, 14, 15, 5, 3, 142000)}

# %% [markdown]
# ### Título, elenco y año de cada película.

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb+srv://analytics:analytics-password@testcris.whr7f.mongodb.net/test?authSource=admin&replicaSet=atlas-x3zgu3-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')
filter={}
project={
    'title': 1, 
    'cast': 1, 
    'year': 1, 
    '_id': 0
}

result = client['sample_mflix']['movies'].find(
  filter=filter,
  projection=project
)

for x in result:
    print('')
    print(x)
# Out:
# tle': 'Spongebob Squarepants 4D Attraction: The Great Jelly Rescue', 'year': 2013}
#
# {'title': "Don't Hug Me I'm Scared", 'year': 2011}
#
# {'title': 'Narco Cultura', 'year': 2013}
#
# {'cast': ['Chemseddine Amar', 'Mark Catuogno', 'Jill Ann Christiano', 'Steef Cuijpers'], 'title': 'Wolf', 'year': 2013}
#
# {'cast': ['Anna Walton', 'Tom Wisdom', 'Tanya Myers', 'Nick Brimble'], 'title': 'Soulmate', 'year': 2013}
#
# {'cast': ['Britt Robertson', 'Molly Hagan', 'Andy Buckley', 'Robert Patrick'], 'title': 'Ask Me Anything', 'year': 2014}
#
# {'cast': ['Gracie Mei Huntsman', 'Jon Huntsman', 'Jerome A. Cohen', 'Chen Guangcheng'], 'title': 'All Eyes and Ears', 'year': 2015}
#
# {'year': 2013, 'title': "Good Ol' Freda", 'cast': ['Freda Kelly', 'Tony Barrow', 'Joey Bower', 'George Harrison']}
#
# {'cast': ['Jason Mac', 'Elliott Armstrong', 'Ana Shaw', 'Catherine Trail'], 'title': 'Infliction', 'year': 2014}
#
# {'cast': ['Haley Joel Osment', 'Geena Davis', 'Alia Shawkat', 'Luke Bracey'], 'title': 'Me Him Her', 'year': 2015}
#
# {'cast': ['Shaun Parkes', 'Emmanuel Akyeampong', 'Joseph Stiglitz', 'Esther Duflo'], 'title': 'Poor Us: An Animated History of Poverty', 'year': 2012}
#
# {'cast': ['Nazif Mujic', 'Senada Alimanovic', 'Semsa Mujic', 'Sandra Mujic'], 'title': 'An Episode in the Life of an Iron Picker', 'year': 2013}
#
# {'cast': ['Raoul Bova', 'Ambra Angiolini', 'Michele Placido', 'Alessandro Gassman'], 'title': "Viva l'Italia", 'year': 2012}
#
# {'cast': ['Darren Berrecloth', 'James Doerfling', 'Andreu Lacondeguy', 'Kurt Sorge'], 'title': 'Where the Trail Ends', 'year': 2012}
#
# {'cast': ['Ed Harris', 'Michael Peèa', 'Eva Longoria', 'Amy Madigan'], 'title': 'Frontera', 'year': 2014}
#
# {'cast': ['Louis C.K.'], 'title': 'Louis C.K. Oh My God', 'year': 2013}
#
# {'cast': ['Alice Eve', 'Bryan Cranston', 'Logan Marshall-Green', 'Ursula Parker'], 'title': 'Cold Comes the Night', 'year': 2013}
#
# {'cast': ['Hans Dagelet', 'Manou Kersting', 'Poal Cairo', 'Dennis Rudge'], 'title': 'Helium', 'year': 2014}
#
# {'cast': ['Louis Garrel', 'Anna Mouglalis', 'Rebecca Convenant', 'Olga Milshtein'], 'title': 'Jealousy', 'year': 2013}
#
# {'cast': ['Victoria Carreras', 'Vèctor Laplace', 'Javier Lombardo', 'Natalia Mateo'], 'title': 'Puerta de Hierro, el exilio de Perèn', 'year': 2012}
#
# {'cast': ['Lisa Smit', 'Barry Atsma', 'Attila èrpa', 'Monic Hendrickx'], 'title': 'Kenau', 'year': 2014}
#
# {'title': 'The Dark Matter of Love', 'year': 2012}
#
# {'cast': ['Peter Ascoli', 'Julian Bond', 'Stephanie Deutsch', 'Richard J. Powell'], 'title': 'Rosenwald', 'year': 2015}
#
# {'cast': ['Linor Abargil', 'Morgan Carpenter', 'Joan Collins', 'Fran Drescher'], 'title': 'Brave Miss World', 'year': 2013}
#
# {'year': 2014, 'title': 'Jauja', 'cast': ['Viggo Mortensen', 'Ghita Nèrby', 'Viilbjèrk Malling Agger', 'Esteban Bigliardi']}
#
# {'title': 'Medora', 'year': 2013}
#
# {'cast': ['Benicio Del Toro', 'Josh Hutcherson', 'Brady Corbet', 'Claudia Traisac'], 'title': 'Escobar: Paradise Lost', 'year': 2014}
#
# {'cast': ['Niall Horan', 'Zayn Malik', 'Liam Payne', 'Harry Styles'], 'title': 'One Direction: This Is Us', 'year': 2013}
#
# {'cast': ['Elena Anaya', 'Nahuel Pèrez Biscayart', 'Angèlica Aragèn', 'Christian Bernal'], 'title': 'They Are All Dead', 'year': 2014}
#
# {'cast': ['Agnes Bruckner', 'Martin Landau', 'Adam Goldberg', 'Graham Patrick Martin'], 'title': 'Anna Nicole', 'year': 2013}
#
# {'cast': ['Aly Michalka', 'Joey Lauren Adams', 'Lou Diamond Phillips', 'Corbin Frost'], 'title': 'Sequoia', 'year': 2014}
#
# {'cast': ['Danny Trejo', 'Kinga Philipps', 'Frank Krueger', 'John Hennigan'], 'title': '20 Ft Below: The Darkness Descending', 'year': 2014}
#
# {'cast': ['Steve Mouzakis', 'Leon Cain', 'Joss McWilliam', 'Matthew Scully'], 'title': 'The Suicide Theory', 'year': 2014}
#
# {'cast': ['Florian David Fitz', 'Henry Hèbchen', 'Marius V. Haas', 'Leslie Malton'], 'title': 'Da geht noch was!', 'year': 2013}
#
# {'cast': ['Rupert Evans', 'Antonia Campbell-Hughes', 'Hannah Hoekstra', 'Kelly Byrne'], 'title': 'The Canal', 'year': 2014}
#
# {'cast': ['Michael Fassbender', 'Niki Lauda', 'Lewis Hamilton', 'Michael Schumacher'], 'title': '1', 'year': 2013}
#
# {'cast': ['Chas Bruns', 'David Cronenberg'], 'title': 'Tales from the Organ Trade', 'year': 2013}
#
# {'title': 'Benji', 'year': 2012}
#
# {'cast': ['Eleanore Pienta', 'Dana Eskelson', 'Molly Plunk', 'Keisha Zollar'], 'title': 'See You Next Tuesday', 'year': 2013}
#
# {'cast': ['Robert Wieckiewicz', 'Julia Kijowska', 'Adam Woronowicz', 'Jacek Braciak'], 'title': 'The Mighty Angel', 'year': 2014}
#
# {'cast': ['Vinay Forrt', 'Lal', 'Sajitha Madathil', 'Riya Saira'], 'title': 'Shutter', 'year': 2012}
#
# {'cast': ['Toni Servillo', 'Valerio Mastandrea', 'Valeria Bruni Tedeschi', 'Michela Cescon'], 'title': 'Long Live Freedom', 'year': 2013}
#
# {'cast': ['Eduardo Fernandez', 'Mauricio Vaca', 'Diego Boggioni', 'Arantxa Uribarri'], 'title': 'Miguel San Miguel', 'year': 2012}
#
# {'cast': ['Morjana Alaoui', 'Nadine Labaki', 'Lubna Azabal', 'Hiam Abbass'], 'title': 'Rock the Casbah', 'year': 2013}
#
# {'year': 2013, 'title': 'Wetlands', 'cast': ['Carla Juri', 'Christoph Letkowski', 'Marlen Kruse', 'Meret Becker']}
#
# {'cast': ['Jayson Blair', 'Macarena Hernèndez', 'Robert Rivard', 'Howard Kurtz'], 'title': 'A Fragile Trust: Plagiarism, Power, and Jayson Blair at the New York Times', 'year': 2013}
#
# {'cast': ['Insoo Kim', 'Shinhyu Kang', 'Seonghwan Kyeong', 'Jeongseok Kim'], 'title': 'The Russian Novel', 'year': 2012}
#
# {'cast': ['Sidney Allison', 'Charon R. Arnold', 'Shay Astar', 'Sam Bean'], 'title': 'All Cheerleaders Die', 'year': 2013}
#
# {'cast': ['Satoshi Tsumabuki', 'Chieko Baishè', 'Takako Matsu', 'Haru Kuroki'], 'title': 'The Little House', 'year': 2014}
#
# {'cast': ['Per Bak Jensen', 'Jonas Bergsèe', 'Bo Elberling', 'Jens Fog Jensen'], 'title': 'The Expedition to the End of the World', 'year': 2013}
#
# {'year': 2014, 'title': 'The Yes Men Are Revolting', 'cast': ['Mike Bonanno', 'Andy Bichlbaum', 'Benadette Chandia Kodili', 'Albert Mwesigwa']}
#
# {'cast': ['Nasser Al Aulaqi', 'Saleha Al Aulaqi', 'Muqbal Al Kazemi', 'Abdul Rahman Barman'], 'title': 'Dirty Wars', 'year': 2013}
#
# {'cast': ['Jèri Lumiste', 'Mait Malmsten', 'Ursula Ratasepp', 'Kèlliki Saldre'], 'title': 'Love Is Blind', 'year': 2013}
#
# {'cast': ['Einar Hillep', 'Ingrid Isotamm', 'Laura Peterson', 'Mirt Preegel'], 'title': 'Risttuules', 'year': 2014}
#
# {'title': 'I Survived a Zombie Holocaust', 'cast': ['Harley Neville', 'Jocelyn Christian', 'Ben Baker', 'Reanin Johannink'], 'year': 2014}
#
# {'cast': ['Pauls Iklavs', 'Reinis Stabins'], 'title': 'Picas', 'year': 2012}
#
# {'cast': ['Yuliya Aug', 'Yana Esipovich', 'Vasiliy Domrachyov', 'Darya Ekamasova'], 'title': 'Nebesnye zheny lugovykh mari', 'year': 2012}
#
# {'cast': ['Hannah Hoekstra', 'Isis Cabolet', 'Robert de Hoog', 'Alex Hendrickx'], 'title': 'App', 'year': 2013}
#
# {'cast': ['Thomas Blumenthal', 'Alice Isaaz', 'Jean-Baptiste Lafarge', "Karim Ait M'Hand"], 'title': 'Smart Ass', 'year': 2014}
#
# {'cast': ['Jennifer Hudson', 'Sarah Hyland', 'Melissa Leo', 'Mitch Rouse'], 'title': 'Call Me Crazy: A Five Film', 'year': 2013}
#
# {'cast': ['Lies Visschedijk', 'Fedja van Huèt', 'Daniel Karaty', 'Lobke de Boer'], 'title': 'Soof', 'year': 2013}
#
# {'cast': ['Luca Barbareschi', 'Jingchu Zhang', 'Carl Ng', 'Frank Crudele'], 'title': 'Something Good: The Mercury Factor', 'year': 2013}
#
# {'cast': ['Ayaka Komatsu', 'Makoto Togashi', 'Toru Tezuka', 'Tateto Serizawa'], 'title': 'Miss Zombie', 'year': 2013}
#
# {'cast': ['Samantha Morton', 'Michael Shannon', 'Natasha Calis', 'Charlie Tahan'], 'title': 'The Harvest', 'year': 2013}
#
# {'cast': ['Maggie Baird', "Finneas O'Connell", 'Lori Nasso', 'David Cowgill'], 'title': 'Life Inside Out', 'year': 2013}
#
# {'cast': ['Nick Blood', 'Nora-Jane Noone', 'Tony Way', 'Lachlan Nieboer'], 'title': 'Brand New-U', 'year': 2015}
#
# {'cast': ['Yeo-jeong Jo', 'Dong-wook Kim', 'Min-jun Kim', 'Ji-Young Park'], 'title': 'The Concubine', 'year': 2012}
#
# {'cast': ['Manolis Mavromatakis', 'Maria Zorba', 'Yiorgos Gallos', 'Antonis Karistinos'], 'title': 'The Enemy Within', 'year': 2013}
#
# {'title': 'Admiral', 'cast': ['Charles Dance', 'Rutger Hauer', 'Barry Atsma', 'Daniel Brocklebank'], 'year': 2015}
#
# {'title': 'American Promise', 'year': 2013}
#
# {'year': 2013, 'title': 'Blackfish', 'cast': ['Tilikum', 'John Hargrove', 'Samantha Berg', 'Mark Simmons']}
#
# {'cast': ['David H. Koch', 'Charles G. Koch', 'Scott Walker', 'Floyd Abrams'], 'title': 'Citizen Koch', 'year': 2013}
#
# {'cast': ['Conrad Anker', 'Grace Chin', 'Jimmy Chin', 'Amee Hinkley'], 'title': 'Meru', 'year': 2015}
#
# {'cast': ['Darren Jacobs', 'Emii', 'Brooke Lewis', 'Claudia Wells'], 'title': 'Starship: Rising', 'year': 2014}
#
# {'cast': ['Alyssa Jewell', 'Andrew Jewell', 'Elizabeth Jewell', 'Willie Jewell'], 'title': 'Rich Hill', 'year': 2014}
#
# {'title': 'Little Hope Was Arson', 'year': 2013}
#
# {'cast': ['Fabio De Luigi', 'Cristiana Capotondi', 'Antonio Catania', 'Anna Bonaiuto'], 'title': 'The Worst Christmas of My Life', 'year': 2012}
#
# {'cast': ['Jakub Gierszal', 'Magdalena Berus', 'èngela Molina', 'Juan Josè Ballesta'], 'title': 'Lasting', 'year': 2013}
#
# {'cast': ['Wajma Bahar', 'Mustafa Abdulsatar', 'Haji Gul Aser', 'Brehna Bahar'], 'title': 'Wajma, an Afghan Love Story', 'year': 2013}
#
# {'cast': ['Brendan Price', 'Nicolas Chapman', 'Molly Malcolm', 'Joshua Zamrycki'], 'title': 'Google and the World Brain', 'year': 2013}
#
# {'cast': ['Ku Jin', 'Hye-jin Han', 'Soo-bin Bae', 'Seul-ong Im'], 'title': '26 Years', 'year': 2012}
#
# {'cast': ['Robert Carlyle', 'Emma Thompson', 'Ashley Jensen', 'Ray Winstone'], 'title': 'The Legend of Barney Thomson', 'year': 2015}
#
# {'cast': ['Georges Khabbaz', 'Lara Rain', 'Emmanuel Khairallah', 'Camille Salameh'], 'title': 'Ghadi', 'year': 2013}
#
# {'cast': ['Josh McConville', 'Hannah Marshall', 'Alex Dimitriades'], 'title': 'The Infinite Man', 'year': 2014}
#
# {'title': 'Documentarian', 'year': 2012}
#
# {'cast': ['Katy Boynton', 'Marco Cochrane', 'Harley K. Dubois', 'Marian Goodell'], 'title': 'Spark: A Burning Man Story', 'year': 2013}
#
# {'cast': ['Silas Carson', 'Joe Hurst', 'Michael Gambon', 'Rory Kinnear'], 'title': 'The Casual Vacancy', 'year': 2015}
#
# {'cast': ['Nellie Gonzalez'], 'title': 'An Unreal Dream: The Michael Morton Story', 'year': 2013}
#
# {'title': 'Matt Shepard Is a Friend of Mine', 'year': 2014}
#
# {'cast': ['Laura Dekker'], 'title': 'Maidentrip', 'year': 2013}
#
# {'cast': ['Ajith Kumar', 'Aarya', 'Nayanthara', 'Tapsee Pannu'], 'title': 'Arrambam', 'year': 2013}
#
# {'cast': ['Akshay Kumar', 'Sonakshi Sinha', 'Freddy Daruwala', 'Sumeet Raghvan'], 'title': 'Holiday', 'year': 2014}
#
# {'year': 2014, 'title': 'Plastic', 'cast': ['Ed Speleers', 'Will Poulter', 'Alfie Allen', 'Sebastian De Souza']}
#
# {'cast': ['Donnie Yen', 'Baoqiang Wang', 'Shengyi Huang', 'Kang Yu'], 'title': 'Iceman', 'year': 2014}
#
# {'cast': ['Seth MacFarlane', 'Charlize Theron', 'Amanda Seyfried', 'Liam Neeson'], 'title': 'A Million Ways to Die in the West', 'year': 2014}
#
# {'cast': ['Haley Lu Richardson', 'Booboo Stewart', 'Max Charles', 'Nicole Arianna Fox'], 'title': 'The Last Survivors', 'year': 2014}
#
# {'cast': ['Sam Berns'], 'title': 'Life According to Sam', 'year': 2013}
#
# {'cast': ['Riton Liebman', 'Lèa Drucker', 'David Murgia', 'Samir Guesmi'], 'title': 'Je suis supporter du Standard', 'year': 2013}
#
# {'cast': ['Sonja Bennett', 'James Caan', 'Danny Trejo', 'Paul Campbell'], 'title': 'Preggoland', 'year': 2014}
#
# {'cast': ['Ben Whishaw', 'Pei-Pei Cheng', 'Andrew Leung', 'Morven Christie'], 'title': 'Lilting', 'year': 2014}
#
# {'cast': ['Steven Adler', 'Frankie Banali', 'Eric Buarque', 'Kevin DuBrow'], 'title': "Quiet Riot: Well Now You're Here, There's No Way Back", 'year': 2014}
#
# {'cast': ['Addison Timlin', 'Veronica Cartwright', 'Anthony Anderson', 'Travis Tope'], 'title': 'The Town That Dreaded Sundown', 'year': 2014}
#
# {'year': 2014, 'title': 'Birdman: Or (The Unexpected Virtue of Ignorance)', 'cast': ['Michael Keaton', 'Emma Stone', 'Kenny Chin', 'Jamahl Garrison-Lowe']}
#
# {'cast': ['Takayuki Yamada', 'Pierre Taki', 'Rirè Furankè', 'Chizuru Ikewaki'], 'title': "The Devil's Path", 'year': 2013}
#
# {'cast': ['Justin Chon', 'Jessika Van', 'In-Pyo Cha', 'Teo Yoo'], 'title': 'Seoul Searching', 'year': 2015}
#
# {'title': 'Bite Size', 'cast': ['Davion Bland', 'Moy Gutierrez', 'Emily Patrick', 'KeAnna Pollard'], 'year': 2014}
#
# {'year': 2013, 'title': 'Starred Up', 'cast': ["Jack O'Connell", 'Gilly Gilchrist', 'Frederick Schmidt', 'Edna Caskey']}
#
# {'cast': ['Ray Liotta', 'Erin Karpluk', 'Dominic Purcell', 'Don MacKay'], 'title': 'Suddenly', 'year': 2013}
#
# {'cast': ['Lewis Matheney'], 'title': 'BMF: The Rise and Fall of a Hip-Hop Drug Empire', 'year': 2012}
#
# {'cast': ['Anna Margaret Hollyman', 'Laura Lemar-Goldsborough', 'Lydia Hyslop', 'Joe Swanberg'], 'title': 'White Reindeer', 'year': 2013}
#
# {'cast': ["Chiara D'Anna", 'Kata Bartsch', 'Sidse Babett Knudsen', 'Monica Swinn'], 'title': 'The Duke of Burgundy', 'year': 2014}
#
# {'cast': ['Akshay Kumar', 'Shiv Pandit', 'Mithun Chakraborty', 'Ronit Roy'], 'title': 'Boss', 'year': 2013}
#
# {'cast': ['Aava Merikanto', 'Lilja Lehto', 'Eija Ahvo', 'Jaakko Saariluoma'], 'title': 'Onneli ja Anneli', 'year': 2014}
#
# {'cast': ['Yoshimasa Hosoya', 'Yèko Hikasa', 'Mamoru Miyano', 'Tamio èki'], 'title': 'Hal', 'year': 2013}
#
# {'cast': ['Simone Nepote Andrè', 'Isa Barzizza', 'Adriano Braidotti', 'Ennio Fantastichini'], 'title': 'Studio illegale', 'year': 2013}
#
# {'cast': ['Madhuri Dixit', 'Juhi Chawla', 'Divya Jagdale', 'Priyanka Bose'], 'title': 'Gulaab Gang', 'year': 2014}
#
# {'cast': ['Andrew Scott', "Hugh O'Conor", 'Peter McDonald', 'Brian Gleeson'], 'title': 'The Bachelor Weekend', 'year': 2013}
#
# {'cast': ['Sullivan Stapleton', 'Jessica De Gouw', 'Alex Russell', 'Megan Holloway'], 'title': 'Cut Snake', 'year': 2014}
#
# {'cast': ['Ranveer Singh', 'Arjun Kapoor', 'Priyanka Chopra', 'Irrfan Khan'], 'title': 'Gunday', 'year': 2014}
#
# {'year': 2013, 'title': 'Septic Man', 'cast': ['Jason David Brown', 'Molly Dunsworth', 'Julian Richings', 'Robert Maillet']}
#
# {'cast': ['Jeong Eun-Chae', 'Sun-kyun Lee', 'Joon-sang Yoo', 'Ji-won Ye'], 'title': "Nobody's Daughter Haewon", 'year': 2013}
#
# {'year': 2013, 'title': 'The Tale of The Princess Kaguya', 'cast': ['Chloè Grace Moretz', 'James Caan', 'Mary Steenburgen', 'Darren Criss']}
#
# {'cast': ['Bartlomiej Topa', 'Arkadiusz Jakubik', 'Julia Kijowska', 'Eryk Lubos'], 'title': 'Traffic Department', 'year': 2013}
#
# {'cast': ['James Bing', 'Jeremy Bing', 'Rosalie Black', 'Dawn Boldrin'], 'title': 'Valentine Road', 'year': 2013}
#
# {'cast': ['Jay Dobyns', 'Paul Ferm', 'Andrew Ferrick', 'Darin Foltz'], 'title': 'Krampus: The Christmas Devil', 'year': 2013}
#
# {'cast': ['Mia Goth', 'Martin McCann', 'Andrew Simpson', 'Douglas Russell'], 'title': 'The Survivalist', 'year': 2015}
#
# {'cast': ['Raoul Bova', 'Michele Placido', 'Valeria Solarino', 'Ambra Angiolini'], 'title': 'La scelta', 'year': 2015}
#
# {'year': 2014, 'title': 'Life After Beth', 'cast': ['Aubrey Plaza', 'Dane DeHaan', 'John C. Reilly', 'Molly Shannon']}
#
# {'cast': ['Levin Liam', 'Helena Phil', 'Vivien Ciskowski', 'Patrick Lorenczat'], 'title': 'Wolfskinder', 'year': 2013}
#
# {'cast': ['Ashley C. Williams', 'Tahyna Tozzi', 'Jack Noseworthy', 'Joel de la Fuente'], 'title': 'Julia', 'year': 2014}
#
# {'cast': ['Thomas Mann', 'RJ Cyler', 'Olivia Cooke', 'Nick Offerman'], 'title': 'Me and Earl and the Dying Girl', 'year': 2015}
#
# {'year': 2014, 'title': 'Whiplash', 'cast': ['Miles Teller', 'J.K. Simmons', 'Paul Reiser', 'Melissa Benoist']}
#
# {'year': 2014, 'title': 'The Fault in Our Stars', 'cast': ['Shailene Woodley', 'Ansel Elgort', 'Nat Wolff', 'Laura Dern']}
#
# {'cast': ['Usain Bolt'], 'title': 'Usain Bolt: The Fastest Man Alive', 'year': 2012}
#
# {'cast': ['Brandon Auret', 'Presley Chweneyagae', 'Brendon Daniels', 'Pallance Dladla'], 'title': 'Avenged', 'year': 2013}
#
# {'cast': ['Johan Leysen', 'Ali Ben Horsting', 'Tygo Bussemakers', 'Bart Slegers'], 'title': 'Son of Mine', 'year': 2015}
#
# {'cast': ['Toni Braxton', 'David Julian Hirsh', 'Nathaniel J. Potvin', 'Paula Shaw'], 'title': 'Twist of Faith', 'year': 2013}
#
# {'cast': ['Vijay Sethupathi', 'Ramya Nambeeshan', 'Aadukalam Naren', 'Karunakaran'], 'title': 'Pizza', 'year': 2012}
#
# {'cast': ['Leon Alan Beiersdorf', 'Matthias Dittmer', 'Lea Draeger', 'Monika Hetterle'], 'title': 'The Strange Little Cat', 'year': 2013}
#
# {'cast': ['Frank Welker', 'Mindy Cohn', 'Grey Griffin', 'Matthew Lillard'], 'title': 'Scooby-Doo! Mask of the Blue Falcon', 'year': 2012}
#
# {'cast': ['Nisa Boonsantear', 'Supanart Jittaleela', 'Apittha Khlaiudom', 'Sushar Manaying'], 'title': 'Yes or No: Come Back to Me', 'year': 2012}
#
# {'cast': ['Miyu Irino', 'Kana Hanazawa', 'Fumi Hirano', 'Gou Maeda'], 'title': 'The Garden of Words', 'year': 2013}
#
# {'cast': ['Seong Ji', 'Ah-jung Kim', 'So-yul Shin', 'Kyeong-jun Kang'], 'title': "Whatcha Wearin'?", 'year': 2012}
#
# {'cast': ['Soo Go', 'Hyo-ju Han', 'Jyu-ni Hyun', 'Seo-Yeon Jin'], 'title': 'Ban-chang-ggo', 'year': 2012}
#
# {'cast': ['Catherine Deneuve', 'Gustave Kervern', 'Fèodor Atkine', 'Pio Marmaè'], 'title': 'In the Courtyard', 'year': 2014}
#
# {'cast': ['Karin Viard', 'Bouli Lanners', 'Claude Gensac', 'Pascal Demolon'], 'title': 'Lulu femme nue', 'year': 2013}
#
# {'cast': ['Dan Cohen', 'Louise Dueno', 'Nell Hardie', 'Norman Hardie'], 'title': 'Alive Inside', 'year': 2014}
#
# {'cast': ['Ryan Metcalf', 'Arjun Gupta', 'Mary Kate Wiles', 'Annet Mahendru'], 'title': 'Bridge and Tunnel', 'year': 2014}
#
# {'cast': ['Denis Shvedov', 'Yuriy Bykov', 'Irina Nizina', 'Ilya Isayev'], 'title': 'The Major', 'year': 2013}
#
# {'year': 2014, 'title': "At the Devil's Door", 'cast': ['Ashley Rickards', 'Nick Eversman', 'Michael Massee', 'Mark Steger']}
#
# {'cast': ['Petri Luukkainen', 'Helena Saarinen', 'Juho Luukkainen', 'Eero Lèyttyjèrvi'], 'title': 'Tavarataivas', 'year': 2013}
#
# {'cast': ['Reneltta Arluk', 'Mary Buscemi', 'Tantoo Cardinal', 'Flint Eagle'], 'title': 'Maèna', 'year': 2013}
#
# {'cast': ['Pachara Chirathivat', 'Jarinporn Joonkiat', 'Pattarasaya Kreuasuwansri', 'David Asavanond'], 'title': 'Countdown', 'year': 2012}
#
# {'cast': ['Quim Gutièrrez', 'èrsula Corberè', 'Belèn Ponce de Leèn', 'Antonio Estrada'], 'title': 'Quièn matè a Bambi?', 'year': 2013}
#
# {'cast': ['Lenny Cooke'], 'title': 'Lenny Cooke', 'year': 2013}
#
# {'cast': ['Kivanè Tatlitug', 'Mert Firat', 'Belèim Bilgin', 'Farah Zeynep Abdullah'], 'title': "The Butterfly's Dream", 'year': 2013}
#
# {'cast': ['Jessie Barr', 'Louis Cancelmi', 'Margaret Daly', 'Caitlin FitzGerald'], 'title': 'Manhattan Romance', 'year': 2015}
#
# {'year': 2013, 'title': 'The French Minister', 'cast': ['Thierry Lhermitte', 'Raphaèl Personnaz', 'Niels Arestrup', 'Bruno Raffaelli']}
#
# {'year': 2013, 'title': "Tyler Perry's A Madea Christmas", 'cast': ['Tyler Perry', 'Anna Maria Horsford', 'Tika Sumpter', 'Eric Lively']}
#
# {'year': 2013, 'title': 'Kevin Hart: Let Me Explain', 'cast': ['Kevin Hart', 'Harry Ratchford', "Will 'Spank' Horton", 'Joey Wells']}
#
# {'cast': ['Meron Getnet', 'Tizita Hagere', 'Abel Abebe', 'Shitaye Abraha'], 'title': 'Difret', 'year': 2014}
#
# {'cast': ['Steven Seagal', 'Ving Rhames', 'Danny Trejo', 'Bren Foster'], 'title': 'Force of Execution', 'year': 2013}
#
# {'cast': ['Gunnar Jènsson', 'Ilmur Kristjènsdèttir', 'Sigurjèn Kjartansson', 'Margrèt Helga Jèhannsdèttir'], 'title': 'Virgin Mountain', 'year': 2015}
#
# {'year': 2014, 'title': "'71", 'cast': ["Jack O'Connell", 'Jack Lowden', 'Paul Popplewell', 'Adam Nagaitis']}
#
# {'cast': ['Suraj Sharma', 'Tony Revolori', 'Prateik', 'Smita Tambe'], 'title': 'Umrika', 'year': 2015}
#
# {'cast': ['Jonathan Gold', 'Allen Salkin'], 'title': 'City of Gold', 'year': 2015}
#
# {'title': 'Keeping Rosy', 'cast': ['Maxine Peake', 'Blake Harrison', 'Sam Hoare', 'Christine Bottomley'], 'year': 2014}
#
# {'cast': ['Noof McEwan', 'Zarrien Masieh', 'Yasmin Mwanza', 'Farshid Rokey'], 'title': 'Leave to Remain', 'year': 2013}
#
# {'cast': ['Matteo Simoni', 'Luigi Lo Cascio', 'Donatella Finocchiaro', 'Evelien Bosmans'], 'title': 'Marina', 'year': 2013}
#
# {'cast': ['Eli Berliner', 'Stuart Blazer', 'Susan Brown', 'Barbara Estrin'], 'title': 'First Cousin Once Removed', 'year': 2012}
#
# {'title': 'Algorithms', 'year': 2013}
#
# {'cast': ['Ellen Dorrit Petersen', 'Henrik Rafaelsen', 'Vera Vitali', 'Marius Kolbenstvedt'], 'title': 'Blind', 'year': 2014}
#
# {'cast': ['Sarah Jaffe'], 'title': 'The Blue Umbrella', 'year': 2013}
#
# {'cast': ['Matt Bomer', 'Stana Katic', 'John Noble', 'Molly C. Quinn'], 'title': 'Superman: Unbound', 'year': 2013}
#
# {'cast': ['Hanno Koffler', 'Max Riemelt', 'Katharina Schèttler', 'Maren Kroymann'], 'title': 'Free Fall', 'year': 2013}
#
# {'cast': ['Sean Bridgers', 'Lauren Ashley Carter', 'Kaitlin Cullum', 'Larry Fessenden'], 'title': 'Jug Face', 'year': 2013}
#
# {'cast': ['Arshad Warsi', 'Amrita Rao', 'Boman Irani', 'Saurabh Shukla'], 'title': 'Jolly LLB', 'year': 2013}
#
# {'cast': ['James Temple', 'Tyler Johnson', 'Sandy Temple', 'Jim Temple'], 'title': 'American Vagabond', 'year': 2013}
#
# {'cast': ['Mike Lopez', 'Lyra Hill', 'Ted Tremper', 'Adebukola Bodunrin'], 'title': 'Crimes Against Humanity', 'year': 2014}
#
# {'cast': ['Jennie Garth', 'Cameron Mathison', 'Kristin Booth', 'Maria del Mar'], 'title': 'Holidaze', 'year': 2013}
#
# {'cast': ['Conner Coffin', 'Parker Coffin', 'Chris Del Moro', 'Leonardo Fioravanti'], 'title': 'Bella Vita', 'year': 2013}
#
# {'cast': ['Tanner Cohen', 'Matthew Camp', 'Ramon O. Torres', 'Judy McLane'], 'title': 'Getting Go, the Go Doc Project', 'year': 2013}
#
# {'year': 2013, 'title': 'New World', 'cast': ['Jung-jae Lee', 'Min-sik Choi', 'Jeong-min Hwang', 'Seong-Woong Park']}
#
# {'year': 2014, 'title': 'Noble', 'cast': ["Deirdre O'Kane", 'Sarah Greene', 'Brendan Coyle', 'Liam Cunningham']}
#
# {'cast': ['Austin Beauchamp', 'Mèlodie Simard', 'Georges St-Pierre'], 'title': 'Takedown: The DNA of GSP', 'year': 2014}
#
# {'cast': ['Sameena Jabeen Ahmed', 'Connor McCarron', 'Gary Lewis', 'Barry Nunney'], 'title': 'Catch Me Daddy', 'year': 2014}
#
# {'cast': ['Kambuzia Partovi', 'Maryam Moqadam', 'Jafar Panahi', 'Hadi Saeedi'], 'title': 'Closed Curtain', 'year': 2013}
#
# {'cast': ['Bawriboon Chanreuang', 'Santisuk Promsiri', 'Udom Taephanit', 'Kerttisak Udomnak'], 'title': 'The Giant King', 'year': 2012}
#
# {'cast': ['Chadwick Brown', 'Tonantzin Carmelo', 'Michael Spears', 'Ron Roggè'], 'title': 'The Activist', 'year': 2014}
#
# {'title': 'We Cause Scenes', 'cast': ['Charlie Todd', 'Ben Folds', 'Daniel Berman', 'Milo Finch'], 'year': 2013}
#
# {'cast': ['èlex Brendemèhl', 'Paraschiva Dragus', 'Maren Eggert', 'Moritz Grove'], 'title': 'Eltern', 'year': 2013}
#
# {'title': 'The Day That Lasted 21 Years', 'cast': ['Stanley Howard Lehman', 'Edson Mazieiro'], 'year': 2012}
#
# {'cast': ['Kate Trotter', 'Peter MacNeill', 'Shauna MacDonald', 'Anna Cyzon'], 'title': 'Tru Love', 'year': 2013}
#
# {'year': 2013, 'title': 'The Retrieval', 'cast': ['Ashton Sanders', 'Tishuan Scott', 'Keston John', 'Bill Oberst Jr.']}
#
# {'cast': ['Maaya Sakamoto', 'Ikkyu Juku', "Ken'ichirè Matsuda", 'Tarusuke Shingaki'], 'title': 'Ghost in the Shell Arise: Border 1 - Ghost Pain', 'year': 2013}
#
# {'cast': ['Tony Benn'], 'title': 'Tony Benn: Will and Testament', 'year': 2014}
#
# {'cast': ['Stefano Altieri', 'Zaira Berrazouga', 'Flavio Bonacci', 'Giorgio Caputo'], 'title': 'Tutti contro tutti', 'year': 2013}
#
# {'cast': ['Stephanie Cumming', 'Christoph Bach', 'Florentèn Groll', 'Elfriede Irrall'], 'title': 'Shirley: Visions of Reality', 'year': 2013}
#
# {'cast': ['Kaleb Shorey', 'Nick Sommer', 'Stephanie Leigh Rose', 'Marla Van Lanen'], 'title': "Don't Go to the Reunion", 'year': 2013}
#
# {'cast': ['Nikos Diamandis', 'Kora Karvouni', 'Youlika Skafida', 'Maria Skoula'], 'title': 'September', 'year': 2013}
#
# {'cast': ['John Lithgow', 'Alfred Molina', 'Tatyana Zbirovskaya', 'Olya Zueva'], 'title': 'Love Is Strange', 'year': 2014}
#
# {'cast': ['Rosmel Bustamante', 'Adriana Calzadilla', 'Simona Chirinos', 'Gonzalo Cubero'], 'title': 'The House at the End of Time', 'year': 2013}
#
# {'cast': ['Elina Abai Kyzy', 'Nasira Mambetova', 'Aziz Muradillayev', 'Adilet Usubaliyev'], 'title': 'Queen of the Mountains', 'year': 2014}
#
# {'cast': ['Adelelmo Jimènez', 'Carlota Rodrèquez'], 'title': 'Penumbra', 'year': 2013}
#
# {'cast': ['Hèctor Noguera', 'Nèstor Guzzini', 'Rolf Becker', 'Nidia Telles'], 'title': 'Mr. Kaplan', 'year': 2014}
#
# {'cast': ['Dakota Blue Richards', 'Karl Davies', 'Brigitte Millar', 'Jack McMullen'], 'title': 'The Quiet Hour', 'year': 2014}
#
# {'cast': ['Raèl Molist', 'Maria Ros', 'Rosemarie Abella', 'Iurie Timbur'], 'title': 'The Plague', 'year': 2013}
#
# {'cast': ['Sergey Puskepalis', 'Anatoliy Belyy', 'Svetlana Khodchenkova', 'Anfisa Vistingauzen'], 'title': 'Metro', 'year': 2013}
#
# {'cast': ['Wesley Clark', 'Peter Coyote'], 'title': 'The Ghost Army', 'year': 2013}
#
# {'title': 'The Escape Artist', 'cast': ['David Tennant', 'Toby Kebbell', 'Gus Barry', 'Brid Brennan'], 'year': 2013}
#
# {'cast': ['Laura Bailey', 'Ogie Banks', 'Cam Clarke', 'Debi Derryberry'], 'title': 'Monster High: Friday Night Frights', 'year': 2013}
#
# {'cast': ['Ton Kas', "Renè van 't Hof", 'Porgy Franssen', 'Ariane Schluter'], 'title': 'Matterhorn', 'year': 2013}
#
# {'cast': ['Sam Riley', 'Tobias Moretti', 'Paula Beer', 'Thomas Schubert'], 'title': 'The Dark Valley', 'year': 2014}
#
# {'cast': ['Gustav Dyekjèr Giese', 'Oscar Dyekjèr Giese', 'Lene Maria Christensen', 'Annemieke Bredahl Peppink'], 'title': 'Northwest', 'year': 2013}
#
# {'cast': ['Aleksandr Yatsenko', 'Anna Kotova', 'Vladimir Korobeynikov', 'Sergey Nasedkin'], 'title': 'A Long and Happy Life', 'year': 2013}
#
# {'cast': ['Andrzej Chyra', 'Mateusz Kosciukiewicz', 'Lukasz Simlat', 'Maja Ostaszewska'], 'title': 'In the Name Of', 'year': 2013}
#
# {'cast': ['Josè Pecina', 'Luis Alberti', 'Everardo Trejo', 'Juan Carlos Medellin'], 'title': 'Carmin Tropical', 'year': 2014}
#
# {'cast': ['Mareks Balmanis', 'Dace Eversa', 'Bruno Henry', 'Kristians Karelins'], 'title': 'Senotaji', 'year': 2013}
#
# {'year': 2014, 'title': 'The Good Lie', 'cast': ['Reese Witherspoon', 'Arnold Oceng', 'Ger Duany', 'Emmanuel Jal']}
#
# {'cast': ['Norman Reedus', 'Matthew Mercer', 'Eric Bauza', 'Kate Higgins'], 'title': 'Iron Man: Rise of Technovore', 'year': 2013}
#
# {'cast': ['Irena Bendovè', 'Patrik Czanik', 'Ladislav Dirda', 'Emilia Dirdovè'], 'title': 'My Dog Killer', 'year': 2013}
#
# {'cast': ['Paul Dietz', 'John Greer', 'Ellee Jane Hounsell', 'Nate Lang'], 'title': 'Whiplash', 'year': 2013}
#
# {'cast': ['Jo-Anne McArthur', 'Jonathan Balcombe', 'Gieri Bolliger', 'Theodora Capaldo'], 'title': 'The Ghosts in Our Machine', 'year': 2013}
#
# {'cast': ['Peter Stormare', 'Justin Chatwin', 'Jane Levy', 'Chloe Rose'], 'title': 'Bang Bang Baby', 'year': 2014}
#
# {'cast': ['Christos Stergioglou', 'Maria Kallimani', 'Yorgos Souxes', 'Theodora Tzimou'], 'title': 'The Eternal Return of Antonis Paraskevas', 'year': 2013}
#
# {'cast': ['Franèois Cluzet', 'Bouli Lanners', 'Corinne Masiero', 'Juana Acosta'], 'title': '11.6', 'year': 2013}
#
# {'cast': ['Joshua Burge', 'Joel Potrykus', 'Teri Ann Nelson', 'Jason Roth'], 'title': 'Buzzard', 'year': 2014}
#
# {'cast': ['Vidyut Jamwal', 'Pooja Chopra', 'Jaideep Ahlawat', 'Dimple Bagrey'], 'title': 'Commando', 'year': 2013}
#
# {'cast': ['Brahim Asloum', 'Steve Suissa', 'Isabella Orsini', 'Patrick Bouchitey'], 'title': 'Victor Young Perez', 'year': 2013}
#
# {'year': 2013, 'title': 'Just a Sigh', 'cast': ['Emmanuelle Devos', 'Gabriel Byrne', 'Gilles Privat', 'Aurèlia Petit']}
#
# {'cast': ['Aleksandr Adabashyan', 'Georgiy Daneliya', 'Nikolay Gubenko', 'Vakhtang Kikabidze'], 'title': 'Ku! Kin-dza-dza', 'year': 2013}
#
# {'cast': ['Seung-ryong Ryu', 'So Won Kal', 'Dal-su Oh', 'Man-shik Jeong'], 'title': 'Miracle in Cell No. 7', 'year': 2013}
#
# {'cast': ['Patrik Karlson', 'Izabella Jo Tschig', 'Per Lèfberg', 'Ahnna Rasch'], 'title': 'LFO', 'year': 2013}
#
# {'cast': ['Yoav Shamir', 'Philip Zimbardo'], 'title': '10%: What Makes a Hero?', 'year': 2013}
#
# {'cast': ['David Bradley', 'Ross Gurney-Randall', 'Roger May', 'Sam Hoare'], 'title': 'An Adventure in Space and Time', 'year': 2013}
#
# {'cast': ['Eray Egilmez', 'Frederick Lau', 'Mona Pirzad', 'Kida Khodr Ramadan'], 'title': 'UMMAH - Unter Freunden', 'year': 2013}
#
# {'cast': ['Silje Salomonsen', 'Tomas Alf Larsen', 'Egil Birkeland', 'Vegar Hoel'], 'title': "It's Only Make Believe", 'year': 2013}
#
# {'cast': ['Mèrocz Adrienn', 'Dèniel Czupi'], 'title': 'Rabbit and Deer', 'year': 2013}
#
# {'cast': ['Victoria Almeida', 'Lautaro Delgado', 'Lucas Lagrè', 'William Prociuk'], 'title': "What's Left of Us", 'year': 2013}
#
# {'year': 2014, 'title': 'Miss Julie', 'cast': ['Colin Farrell', 'Jessica Chastain', 'Samantha Morton', 'Nora McMenamy']}
#
# {'cast': ['Tadanobu Asano', 'Elena Kazan', 'Nathalia Acevedo', 'Brenda Mage'], 'title': 'Ruined Heart: Another Lovestory Between a Criminal & a Whore', 'year': 2014}
#
# {'cast': ['Yè Aoi', 'Jessica Boone', 'Ayano Fukuda', 'Arata Furuta'], 'title': 'Harlock: Space Pirate', 'year': 2013}
#
# {'cast': ['Danielle Panabaker', "Matt O'Leary", 'George Finn', 'John Rhys-Davies'], 'title': 'Time Lapse', 'year': 2014}
#
# {'cast': ['Matthias Schweighèfer', 'Ruth-Maria Kubitschek', 'August Diehl', 'Anna Bederke'], 'title': 'Frau Ella', 'year': 2013}
#
# {'cast': ['Eitan Cunio', 'David Cunio', 'Moshe Ivgy', 'Shirli Deshe'], 'title': 'Youth', 'year': 2013}
#
# {'cast': ['Reza Attaran', "Merila Zare'i", 'Akbar Abdi', 'Vishka Asayesh'], 'title': 'I Feel Sleepy', 'year': 2012}
#
# {'title': 'Love Games', 'year': 2012}
#
# {'cast': ['Jasna Fritzi Bauer', 'Ulrich Noethen', 'Max Hegewald', 'Vladimir Burlakov'], 'title': 'Broken Glass Park', 'year': 2013}
#
# {'cast': ['Chelsea Jenish', 'Sofia Banzhaf', 'Robert Nolan', 'Jen Pogue'], 'title': 'Silent Retreat', 'year': 2013}
#
# {'title': 'The Scopia Effect', 'cast': ['Joanna Ignaczewska', 'Louis Labovitch', 'Akira Koieyama', 'Genevieve Sibayan'], 'year': 2014}
#
# {'cast': ['Steven Weber', 'Andrew Francis', 'Michelle Harrison', 'Michael Eklund'], 'title': 'Tom Dick & Harriet', 'year': 2013}
#
# {'cast': ['Candy', 'Terri Lyne Carrington', 'Quincy Cavers', 'Bill Cosby'], 'title': "Keep on Keepin' On", 'year': 2014}
#
# {'cast': ['Richard Berkowitz', 'Timothy Ray Brown', 'Michael Callen', 'Kenneth Cole'], 'title': 'The Battle of Amfar', 'year': 2013}
#
# {'title': 'Ad Inexplorata', 'cast': ['Mark Strong', 'Sanaa Lathan', 'Charles Baker', 'Bettina Skye'], 'year': 2015}
#
# {'cast': ['Naseeruddin Shah', 'Madhuri Dixit', 'Arshad Warsi', 'Huma Qureshi'], 'title': 'Dedh Ishqiya', 'year': 2014}
#
# {'cast': ['Kère Conradi', 'Huyen Huynh', 'Anders Baasmo Christiansen', 'Adil Halitaj'], 'title': 'In Order of Disappearance', 'year': 2014}
#
# {'title': 'The Smoke Seller', 'year': 2012}
#
# {'cast': ['Tony Abou-Ganim', 'Eric Alperin', 'Jeff Bell', 'John Besh'], 'title': 'Hey Bartender', 'year': 2013}
#
# {'cast': ['David Phillip Carollo', "Melissa O'Brien", 'Nicolette le Faye', 'Dave Gamble'], 'title': 'Call Girl of Cthulhu', 'year': 2014}
#
# {'cast': ['Billie Joe Armstrong', 'Michael Mayer', 'Steven Hoggett', 'Tom Kitt'], 'title': 'Broadway Idiot', 'year': 2013}
#
# {'cast': ['Janne Reinikainen', 'Maria Jèrvenhelmi', 'Antti Raivio', 'Markku Peltola'], 'title': 'Kalervo Palsa ja kuriton kèsi', 'year': 2013}
#
# {'cast': ['Jonathan Da Rosa', 'Tatiana Gimènez', 'Mirella Pascual', 'Claudia Cantero'], 'title': 'History of Fear', 'year': 2014}
#
# {'cast': ['Koen De Bouw', 'Johan Leysen', 'Veerle Baetens', 'Jappe Claes'], 'title': 'Het Vonnis', 'year': 2013}
#
# {'cast': ['Patricia Clarkson', 'Scott Speedman', 'Tim Roth', 'Callum Keith Rennie'], 'title': 'October Gale', 'year': 2014}
#
# {'year': 2014, 'title': 'Night at the Museum: Secret of the Tomb', 'cast': ['Ben Stiller', 'Robin Williams', 'Owen Wilson', 'Steve Coogan']}
#
# {'year': 2013, 'title': 'Locke', 'cast': ['Tom Hardy', 'Olivia Colman', 'Ruth Wilson', 'Andrew Scott']}
#
# {'cast': ['Michael Shannon', 'Nicholas Hoult', 'Elle Fanning', 'Kodi Smit-McPhee'], 'title': 'Young Ones', 'year': 2014}
#
# {'cast': ['Brooke Langton', 'David Strathairn', 'Stephen Dorff', 'Carlos Bardem'], 'title': "Oliver's Deal", 'year': 2015}
#
# {'cast': ['Marc Velasco', 'Noè Blancafort', 'Salvador Llès', 'Victoria Roldèn'], 'title': 'Fist of Jesus', 'year': 2012}
#
# {'cast': ['Manuela Martelli', 'Susana Pampin', 'Rafael Federman', 'Laura Paredes'], 'title': 'Two Shots Fired', 'year': 2014}
#
# {'year': 2014, 'title': 'Saint Laurent', 'cast': ['Gaspard Ulliel', 'Jèrèmie Renier', 'Louis Garrel', 'Lèa Seydoux']}
#
# {'year': 2014, 'title': 'Yves Saint Laurent', 'cast': ['Pierre Niney', 'Guillaume Gallienne', 'Charlotte Le Bon', 'Laura Smet']}
#
# {'cast': ['Emile Hirsch', 'Holliday Grainger', 'Sarah Hyland', 'Elizabeth Reaser'], 'title': 'Bonnie and Clyde', 'year': 2013}
#
# {'year': 2013, 'title': 'Life of a King', 'cast': ['Cuba Gooding Jr.', 'Dennis Haysbert', 'LisaGay Hamilton', 'Thurston Hill']}
#
# {'cast': ['Shèta Chiyo', 'Shunsuke Daitè', 'Narushi Ikeda', 'Nana Katase'], 'title': 'HK: Forbidden Super Hero', 'year': 2013}
#
# {'cast': ['Patrick Moote', 'Axel Braun', 'Jonah Falcon', 'Allie Haze'], 'title': 'UnHung Hero', 'year': 2013}
#
# {'cast': ['Dominic West', 'Helena Bonham Carter', 'Greg Hicks', 'Jeff Mash'], 'title': 'Burton and Taylor', 'year': 2013}
#
# {'cast': ['Miranda Raison', 'Sam Keeley', 'Daniella Kertesz', 'Elarica Gallacher'], 'title': 'AfterDeath', 'year': 2015}
#
# {'cast': ['Hiam Abbass', 'Ghazi Albuliwi', 'Omer Barnea', 'Thom Bishops'], 'title': 'Peace After Marriage', 'year': 2013}
#
# {'cast': ['Lèa Seydoux', 'Vincent Lindon', 'Clotilde Mollet', 'Hervè Pierre'], 'title': 'Diary of a Chambermaid', 'year': 2015}
#
# {'cast': ['James Norton', 'Will Tudor', 'Eleanor Wyld', 'Josie Lawrence'], 'title': 'Bonobo', 'year': 2014}
#
# {'cast': ['Brad Pitt', 'Shia LaBeouf', 'Logan Lerman', 'Michael Peèa'], 'title': 'Fury', 'year': 2014}
#
# {'year': 2013, 'title': 'Finding Vivian Maier', 'cast': ['Vivian Maier', 'John Maloof', 'Daniel Arnaud', 'Simon Amèdè']}
#
# {'cast': ['Sultan Aka', 'Ita Ever', 'Toompere Jr. jr Hendrik', 'Peeter Jakobi'], 'title': 'Living Images', 'year': 2013}
#
# {'cast': ['Robin Aubert', 'Marilyn Castonguay', 'Violette Chauveau', 'Sarianne Cormier'], 'title': 'Miraculum', 'year': 2014}
#
# {'cast': ['Piolo Pascual', 'Gerald Anderson', 'Joel Torre', 'Joey Marquez'], 'title': 'On the Job', 'year': 2013}
#
# {'year': 2014, 'title': 'The Riot Club', 'cast': ['Thomas Arnold', 'Harry Lloyd', 'Amber Anderson', 'Max Irons']}
#
# {'year': 2013, 'title': 'Ida', 'cast': ['Agata Kulesza', 'Agata Trzebuchowska', 'Dawid Ogrodnik', 'Jerzy Trela']}
#
# {'cast': ['Marcel Bender', 'Maximilian Brauer', 'Samia Muriel Chancrin', 'Felix Defèr'], 'title': "The King's Surrender", 'year': 2014}
#
# {'year': 2015, 'title': 'Blackhat', 'cast': ['Chris Hemsworth', 'Leehom Wang', 'Wei Tang', 'Viola Davis']}
#
# {'cast': ['Anna Geislerovè', 'Stanislav Majer', 'Jirè Cernè', 'Kristèna Novèkovè'], 'title': 'Honeymoon', 'year': 2013}
#
# {'cast': ['Jowita Budnik', 'Zbigniew Walerys', 'Antoni Pawlicki', 'Artur Steranko'], 'title': 'Papusza', 'year': 2013}
#
# {'year': 2014, 'title': 'The Salvation', 'cast': ['Mads Mikkelsen', 'Eva Green', 'Jeffrey Dean Morgan', 'Eric Cantona']}
#
# {'cast': ['Scott Martin', 'Stephanie Beran', 'Ross Brooks', 'Ozman Sirgood'], 'title': 'P-51 Dragon Fighter', 'year': 2014}
#
# {'cast': ["Josh O'Connor", 'Hannah Arterton', 'Rea Mole', 'Daniel Metz'], 'title': 'Hide and Seek', 'year': 2014}
#
# {'cast': ['Devid Striesow', 'Sebastian Blomberg', 'Katharina Schèttler', 'Jaymes Butler'], 'title': 'Zeit der Kannibalen', 'year': 2014}
#
# {'year': 2014, 'title': 'The Sleepwalker', 'cast': ['Gitte Witt', 'Christopher Abbott', 'Stephanie Ellis', 'Brady Corbet']}
#
# {'cast': ['Ian Ziering', 'Tara Reid', 'John Heard', 'Cassie Scerbo'], 'title': 'Sharknado', 'year': 2013}
#
# {'cast': ['Jukka-Pekka Siili', 'Jukka Kèrkkèinen', 'Niina Koponen', 'Niko Vakkuri'], 'title': 'Korso', 'year': 2014}
#
# {'cast': ['Rosamund Pike', 'David Tennant', 'Billy Connolly', 'Ben Miller'], 'title': 'What We Did on Our Holiday', 'year': 2014}
#
# {'cast': ['Alysa King', 'Samora Smallwood', 'Bart Rochon', 'Aaron Chartrand'], 'title': 'Berkshire County', 'year': 2014}
#
# {'cast': ['Britt Robertson', 'Scott Eastwood', 'Alan Alda', 'Jack Huston'], 'title': 'The Longest Ride', 'year': 2015}
#
# {'cast': ['Emerson Collins', 'Leslie Jordan', 'Dale Dickey', 'Willam Belli'], 'title': 'Southern Baptist Sissies', 'year': 2013}
#
# {'cast': ['Mitchell Jarvis', 'Marcus Hackney', 'Justin Absatz', 'Phyllis Bowen'], 'title': "Fool's Day", 'year': 2013}
#
# {'cast': ['Bahman Mohasses'], 'title': 'Fifi Howls from Happiness', 'year': 2013}
#
# {'cast': ['Adam Winfield', 'Christopher Winfield', 'Emma Winfield', 'Alaina Winfield'], 'title': 'The Kill Team', 'year': 2013}
#
# {'year': 2013, 'title': "The Strange Color of Your Body's Tears", 'cast': ['Klaus Tange', 'Ursula Bedena', 'Joe Koener', 'Birgit Yew']}
#
# {'title': 'Nobody Wants the Night', 'cast': ['Juliette Binoche', 'Gabriel Byrne', 'Rinko Kikuchi', 'Matt Salinger'], 'year': 2015}
#
# {'cast': ['Matt Berninger', 'Aaron Dessner', 'Bryce Dessner', 'Bryan Devendorf'], 'title': 'Mistaken for Strangers', 'year': 2013}
#
# {'year': 2014, 'title': 'Two Days, One Night', 'cast': ['Marion Cotillard', 'Fabrizio Rongione', 'Catherine Salèe', 'Batiste Sornin']}
#
# {'title': 'Desolate', 'cast': ['Jez Bonham', 'Justin Sproule', 'Teagan Vincze'], 'year': 2013}
#
# {'cast': ['Thommy Berggren', 'Kate Pickett', 'Richard Wilkinson'], 'title': 'Decency', 'year': 2013}
#
# {'cast': ['Richie Jen', 'Mavis Fan', 'Chin-Hang Shih', 'Kimi Hsia'], 'title': 'Will You Still Love Me Tomorrow?', 'year': 2013}
#
# {'cast': ['Univ. Miami Indian Students Assoc.', 'Karl Bakke', 'John Barrett', 'Jon Bon Jovi'], 'title': 'Two: The Story of Roman & Nyro', 'year': 2013}
#
# {'cast': ['Da-wit Lee', 'Sung-Jun', 'Sung-ha Jo', 'Kkobbi Kim'], 'title': 'Pluto', 'year': 2012}
#
# {'year': 2013, 'title': 'In Bloom', 'cast': ['Lika Babluani', 'Mariam Bokeria', 'Zurab Gogaladze', 'Data Zakareishvili']}
#
# {'cast': ['Sveva Alviti', 'Stefano Ambrogi', 'Jonis Bashir', 'Giulia Bertini'], 'title': 'Out of the Blue', 'year': 2013}
#
# {'cast': ['Marine Vacth', 'Gèraldine Pailhas', 'Frèdèric Pierrot', 'Fantin Ravat'], 'title': 'Young & Beautiful', 'year': 2013}
#
# {'year': 2014, 'title': 'Rosewater', 'cast': ['Gael Garcèa Bernal', 'Kim Bodnia', 'Dimitri Leonidas', 'Haluk Bilginer']}
#
# {'year': 2014, 'title': "Devil's Due", 'cast': ['Allison Miller', 'Zach Gilford', 'Sam Anderson', 'Roger Payano']}
#
# {'cast': ['Tatsuhisa Suzuki', 'Takako Honda', 'Wataru Takagi', 'Yuko Kaida'], 'title': 'Kick-Heart', 'year': 2013}
#
# {'year': 2014, 'title': 'The One I Love', 'cast': ['Mark Duplass', 'Elisabeth Moss', 'Ted Danson', 'Kiana Cason']}
#
# {'cast': ['Haluk Bilginer', 'Melisa Sèzen', 'Demet Akbag', 'Ayberk Pekcan'], 'title': 'Winter Sleep', 'year': 2014}
#
# {'cast': ['Pier Giorgio Bellocchio', 'Stefano Cassetti', 'Ludovico Di Martino', 'Germano Gentile'], 'title': 'The Third Half', 'year': 2013}
#
# {'cast': ['Danny Cheng', 'Andrew Eads', 'Jamie Eng', 'Luis Enriquez'], 'title': 'Code Black', 'year': 2013}
#
# {'cast': ['Sophie Marceau', 'Franèois Cluzet', 'Lisa Azuelos', 'Alexandre Astier'], 'title': 'Quantum Love', 'year': 2014}
#
# {'cast': ['Abigail Breslin', 'Alexa PenaVega', 'Sean Bean', 'James Purefoy'], 'title': 'Wicked Blood', 'year': 2014}
#
# {'cast': ['Marina Symeou', 'Marianthi Pantelopoulou', 'Nikos Georgakis', 'Giorgos Kafetzopoulos'], 'title': 'Na kathesai kai na koitas', 'year': 2013}
#
# {'cast': ['Tadanobu Asano', 'Tatsuya Fuji', 'Fumi Nikaidè', 'Takahiro Miura'], 'title': 'My Man', 'year': 2014}
#
# {'year': 2014, 'title': 'Phoenix', 'cast': ['Nina Hoss', 'Ronald Zehrfeld', 'Nina Kunzendorf', 'Trystan Pètter']}
#
# {'cast': ['Mark Chao', 'Geng Han', 'Zishan Yang', 'Shuying Jiang'], 'title': 'So Young', 'year': 2013}
#
# {'title': 'Krot na more', 'year': 2012}
#
# {'cast': ['Scoot McNairy', 'Shea Whigham'], 'title': 'The Life and Mind of Mark DeFriest', 'year': 2014}
#
# {'cast': ['Joseph Fiennes', 'Tom Cavanagh', 'Megan Charpentier', 'Valentina Lodovini'], 'title': 'The Games Maker', 'year': 2014}
#
# {'cast': ['Claudio Bisio', 'Kasia Smutniak', 'Beppe Fiorello', 'Remo Girone'], 'title': 'Benvenuto Presidente!', 'year': 2013}
#
# {'cast': ['Bhole Baba', 'Hatha Yogi Baba', 'Pant Shirt Baba', 'Baby Bajrangi'], 'title': 'Faith Connections', 'year': 2013}
#
# {'cast': ['Kari Ann Grènsund', 'Trond Hèvik', 'Trond Brènne', 'Kère Conradi'], 'title': 'Solan og Ludvig - Jul i Flèklypa', 'year': 2013}
#
# {'year': 2014, 'title': 'Veronica Mars', 'cast': ['Kristen Bell', 'Jason Dohring', 'Enrico Colantoni', 'Chris Lowell']}
#
# {'cast': ['Whit Hertford', 'Don McManus', 'James Kyson', 'Robyn Cohen'], 'title': 'The Perfect 46', 'year': 2014}
#
# {'cast': ['Anthony Chan', 'Siu-Ho Chin', 'Fat Chung', 'Kara Hui'], 'title': 'Rigor Mortis', 'year': 2013}
#
# {'cast': ['Michelle Mylett', 'Cody Ray Thompson', 'Adam Christie', 'Ana Alic'], 'title': 'Antisocial', 'year': 2013}
#
# {'cast': ['Mateusz Banasiuk', 'Marta Nieradkiewicz', 'Bartosz Gelner', 'Katarzyna Herman'], 'title': 'Floating Skyscrapers', 'year': 2013}
#
# {'cast': ['Mario Maurer', 'Davika Hoorne', 'Nattapong Chartpong', 'Pongsatorn Jongwilak'], 'title': 'Pee Mak', 'year': 2013}
#
# {'cast': ['Leo Fafard', 'Amy Matysio', 'Sarah Lind', 'Corinne Conley'], 'title': 'WolfCop', 'year': 2014}
#
# {'cast': ['Michael Eklund', 'Sara Canning', 'Christopher Heyerdahl', 'Charlie Carrick'], 'title': 'Eadweard', 'year': 2015}
#
# {'cast': ['Chris Rock', 'Rosario Dawson', 'J.B. Smoove', 'Gabrielle Union'], 'title': 'Top Five', 'year': 2014}
#
# {'year': 2014, 'title': 'The Little Death', 'cast': ['Bojana Novakovic', 'Damon Herriman', 'Josh Lawson', 'Ben Lawson']}
#
# {'cast': ['Marcin Dorocinski', 'Maja Ostaszewska', 'Patrick Wilson', 'Dimitri Bilov'], 'title': 'Jack Strong', 'year': 2014}
#
# {'year': 2014, 'title': 'America: Imagine the World Without Her', 'cast': ["Dinesh D'Souza", 'Barack Obama', 'Josh Bonzie', 'Rich Bentz']}
#
# {'title': 'Way Beyond Weight', 'year': 2012}
#
# {'cast': ['Peter Cullen', 'Frank Welker', 'Steve Blum', 'Jeffrey Combs'], 'title': 'Transformers Prime Beast Hunters: Predacons Rising', 'year': 2013}
#
# {'year': 2014, 'title': 'The Interview', 'cast': ['James Franco', 'Seth Rogen', 'Lizzy Caplan', 'Randall Park']}
#
# {'cast': ['Ryan Piers Williams', 'America Ferrera', 'Jon Paul Phillips', 'David Harbour'], 'title': 'X/Y', 'year': 2014}
#
# {'cast': ['Hannah Herzsprung', 'Florian Stetter', 'Henriette Confurius', 'Claudia Messner'], 'title': 'Beloved Sisters', 'year': 2014}
#
# {'cast': ['Dorian Boguta', 'Dragos Bucur', 'Eugen Lumezianu', 'Silvia Morosanu'], 'title': 'Love Building', 'year': 2013}
#
# {'year': 2014, 'title': 'Starry Eyes', 'cast': ['Alex Essoe', 'Amanda Fuller', 'Noah Segan', 'Fabianne Therese']}
#
# {'cast': ['Al Armendariz', 'Kindra Arnesen', 'Lon Burnam', 'Lois Capps'], 'title': 'Gasland Part II', 'year': 2013}
#
# {'cast': ['Franèois Damiens', 'Gèraldine Nakache', 'Lucien Jean-Baptiste', 'Anne Le Ny'], 'title': 'Je fais le mort', 'year': 2013}
#
# {'cast': ['Do-yeon Jeon', 'Soo Go', 'Claudette Lalè', 'Michèle Raingeval'], 'title': 'Jibeuro ganeun gil', 'year': 2013}
#
# {'cast': ['Rani Mukerji', 'Randeep Hooda', 'Saqib Saleem', 'Nawazuddin Siddiqui'], 'title': 'Bombay Talkies', 'year': 2013}
#
# {'cast': ['John Lynch', 'Morjana Alaoui', 'Craig Conway', 'Antonia Thomas'], 'title': 'The Hybrid', 'year': 2014}
#
# {'cast': ['Brian Gleeson', 'Emma Eliza Regan', 'Maura Foley', 'Emma Willis'], 'title': 'Darkness on the Edge of Town', 'year': 2014}
#
# {'cast': ['Kristoffer Polaha', 'Laura Regan', 'Peter Mackenzie', 'Greg Germann'], 'title': 'Atlas Shrugged: Who Is John Galt?', 'year': 2014}
#
# {'cast': ['Christian Clavier', 'Chantal Lauby', 'Ary Abittan', 'Medi Sadoun'], 'title': 'Serial (Bad) Weddings', 'year': 2014}
#
# {'title': 'All of Me', 'year': 2013}
#
# {'cast': ['Manuel Vignau', 'Mateo Chiarino', 'Luz Palazèn', 'Antonia De Michelis'], 'title': 'Hawaii', 'year': 2013}
#
# {'year': 2014, 'title': 'Kingsman: The Secret Service', 'cast': ['Adrian Quinton', 'Colin Firth', 'Mark Strong', 'Jonno Davies']}
#
# {'year': 2014, 'title': 'Leviathan', 'cast': ['Aleksey Serebryakov', 'Elena Lyadova', 'Vladimir Vdovichenkov', 'Roman Madyanov']}
#
# {'cast': ['Laurent Lucas', 'Aurèlien Recoing', 'Audrey Dana', 'Pascal Greggory'], 'title': 'Le mètis de Dieu', 'year': 2013}
#
# {'cast': ['Janusz Gajos', 'Kazimierz Kaczor', 'Wojciech Zoladkowicz', 'Robert Olech'], 'title': 'The Closed Circuit', 'year': 2013}
#
# {'cast': ['Anu Sinisalo', 'Ville Virtanen', 'Kai Vaine', 'Wanda Dubiel'], 'title': 'No Thank You', 'year': 2014}
#
# {'cast': ['Tomoko Karina', 'Akihiro Kitamura', 'Hitomi Katayama', 'Shèta Sometani'], 'title': 'Tokyo Tribe', 'year': 2014}
#
# {'cast': ['Kate Moran', 'Niels Schneider', 'Nicolas Maury', 'Eric Cantona'], 'title': 'You and the Night', 'year': 2013}
#
# {'cast': ['Rob Lowe', 'Will Rothhaar', 'Jack Noseworthy', 'Casey Siemaszko'], 'title': 'Killing Kennedy', 'year': 2013}
#
# {'title': 'The Childhood of a Leader', 'cast': ['Robert Pattinson', 'Liam Cunningham', 'Stacy Martin', 'Bèrènice Bejo'], 'year': 2015}
#
# {'cast': ['Sonia Suhl', 'Lars Mikkelsen', 'Sonja Richter', 'Jakob Oftebro'], 'title': 'When Animals Dream', 'year': 2014}
#
# {'title': 'Everything I Can See From Here', 'year': 2013}
#
# {'cast': ['Martèn Altomaro', 'Irineo Alvarez', 'Moises Arizmendi', 'Irene Azuela'], 'title': 'The Last Call', 'year': 2013}
#
# {'year': 2015, 'title': 'Furious 7', 'cast': ['Vin Diesel', 'Paul Walker', 'Jason Statham', 'Michelle Rodriguez']}
#
# {'year': 2013, 'title': 'Bastards', 'cast': ['Vincent Lindon', 'Chiara Mastroianni', 'Julie Bataille', 'Michel Subor']}
#
# {'cast': ['Gavin Andresen', 'Brian Armstrong', 'Margaux Avedisian', 'Vitalik Buterin'], 'title': 'The Rise and Rise of Bitcoin', 'year': 2014}
#
# {'cast': ['Dan Abnett', 'Geoff Barrow', 'Emma Beeby', 'Karen Berger'], 'title': 'Future Shock! The Story of 2000AD', 'year': 2014}
#
# {'year': 2014, 'title': '3 Hearts', 'cast': ['Benoèt Poelvoorde', 'Charlotte Gainsbourg', 'Chiara Mastroianni', 'Catherine Deneuve']}
#
# {'cast': ['Julius Feldmeier', 'Sascha Alexander Gersak', 'Annika Kuhl', 'Swantje Kohlhof'], 'title': 'Nothing Bad Can Happen', 'year': 2013}
#
# {'cast': ['Carmina Barrios', 'Paco Casaus', 'Marèa Leèn', 'Mari Paz Sayago'], 'title': 'Carmina y amèn.', 'year': 2014}
#
# {'cast': ['Edward Akrout', 'Matt Barber', 'Megan Maczko', 'Helen Bradbury'], 'title': 'Deadly Virtues: Love.Honour.Obey.', 'year': 2014}
#
# {'cast': ['Milo Cawthorne', 'Olivia Tennet', 'Ari Boyland', 'Fleur Saville'], 'title': 'Blood Punch', 'year': 2013}
#
# {'cast': ['Somnath Awghade', 'Sanjay Chaudhri', 'Chhaya Kadam', 'Kishore Kadam'], 'title': 'Fandry', 'year': 2013}
#
# {'cast': ['Marc Basil', 'Jeffrey Brewer', 'Garlan Green', 'Michael Wren Gucciardo'], 'title': 'Silenced', 'year': 2014}
#
# {'cast': ['Jeong-min Hwang', 'Woong-in Jung', 'Yo-won Lee', 'Jung-min Park'], 'title': 'Fists of Legend', 'year': 2013}
#
# {'cast': ['Cody Linley', 'Patrick Warburton', 'Lauren Holly', 'Alyson Stoner'], 'title': 'Hoovey', 'year': 2015}
#
# {'cast': ['Stephen Hawking', 'Buzz Aldrin', 'Gordon Berry', 'Richard Branson'], 'title': 'Hawking', 'year': 2013}
#
# {'cast': ['Vinay Virmani', 'Adrianne Palicki', 'Kunal Nayyar', 'Lillete Dubey'], 'title': 'Dr. Cabbie', 'year': 2014}
#
# {'cast': ['Vegar Hoel', 'èrjan Gamst', 'Martin Starr', 'Jocelyn DeBoer'], 'title': 'Dead Snow 2: Red vs. Dead', 'year': 2014}
#
# {'cast': ['Jean-Carl Boucher', 'Sandrine Bisson', 'Claudio Colangelo', 'Laurent-Christophe De Ruelle'], 'title': '1987', 'year': 2014}
#
# {'cast': ['Frank Aendenboom', 'Silke Becu', 'Luc Caals', 'Veerle De Jonghe'], 'title': 'Crimi Clowns: De Movie', 'year': 2013}
#
# {'cast': ['Tahar Rahim', 'Lèa Seydoux', 'Olivier Gourmet', 'Denis Mènochet'], 'title': 'Grand Central', 'year': 2013}
#
# {'cast': ['Ruby Lin', 'Jue Huang', 'Yongdai Ding', 'Yu Bin'], 'title': 'Fallen City', 'year': 2011}
#
# {'cast': ['Renzo Gariup', 'Marco Marchese', 'Lidia Zabrieszach'], 'title': 'Across the River', 'year': 2013}
#
# {'cast': ['Sara Gorsky', 'Cole Simon', 'Tanya Thai McBride', 'Clayton Stamper'], 'title': 'Chrysalis', 'year': 2014}
#
# {'cast': ['Lily Tomlin', 'Pat Derby', 'Colleen Kinzley', 'Jeff Kinzley'], 'title': 'An Apology to Elephants', 'year': 2013}
#
# ...
#
# {'cast': ['Hillary Berg', 'Beck DeRobertis', 'Paul Dickinson', 'Alex Karpovsky'], 'title': 'Tired Moonlight', 'year': 2015}
#
# {'cast': ['Michael Dowd', 'Ken Eurell', 'Walter Yurkiw', 'Chickie'], 'title': 'The Seven Five', 'year': 2014}
#
# {'cast': ['Marèa Mercedes Coroy', 'Marèa Telèn', 'Manuel Manuel Antèn', 'Justo Lorenzo'], 'title': 'Ixcanul Volcano', 'year': 2015}
#
# {'cast': ['Peter Bogdanovich', 'Orson Welles'], 'title': 'Magician: The Astonishing Life and Work of Orson Welles', 'year': 2014}
#
# {'title': 'Dark Horse', 'year': 2015}
#
# {'cast': ['Marcello Macchia', 'Luigi Luciano', 'Enrico Venti', 'Lavinia Longhi'], 'title': 'Italiano medio', 'year': 2015}
#
# {'cast': ['Bill Darnell', 'David Garrick', 'Bobbi Hunter', 'Emily Hunter'], 'title': 'How to Change the World', 'year': 2015}
#
# {'cast': ['Marlon Brando'], 'title': 'Listen to Me Marlon', 'year': 2015}
#
# {'cast': ['Cobie Smulders', 'Anders Holm', 'Gail Bean', 'Elizabeth McGovern'], 'title': 'Unexpected', 'year': 2015}
#
# {'cast': ['Katie Savoy', 'Chris Riedell', 'Lincoln Hoppe', 'Chris Dinh'], 'title': 'Crush the Skull', 'year': 2015}
#
# {'cast': ['Sven Ahlstrèm', 'Mats Blomgren', 'Stefan Cronwall', 'Loa Ek'], 'title': 'The Here After', 'year': 2015}
#
# {'cast': ['Carl Apfel', 'Iris Apfel'], 'title': 'Iris', 'year': 2014}
#
# {'cast': ['Olivia Corsini', 'Serge Nicolai', 'Pancho Garcia Aguirre', 'Shaghayegh Beheshti'], 'title': 'Olmo & the Seagull', 'year': 2014}
#
# {'cast': ['Oussama Addi', 'Elsie de Brauw', 'Ayoub Elasri', 'Olivia Lonsdale'], 'title': 'Prince', 'year': 2015}
#
# {'cast': ['Konstantin Balakirev', 'Pavel Basov', 'Darya Ekamasova', 'Georghi Iobadze'], 'title': 'Angels of Revolution', 'year': 2014}
#
# {'cast': ['Mark Reay'], 'title': 'Homme Less', 'year': 2014}
#
# {'cast': ['Angelica Panganiban', 'JM de Guzman', 'Joem Bascon', 'Carlos Castano'], 'title': 'That Thing Called Tadhana', 'year': 2014}
#
# {'cast': ['Winona Mae', 'Julia Pott'], 'title': 'World of Tomorrow', 'year': 2015}
#
# {'cast': ['Eri Fukatsu', 'Tadanobu Asano', 'Masaaki Akahori', 'Yè Aoi'], 'title': 'Journey to the Shore', 'year': 2015}
#
# {'cast': ['Golshifteh Farahani', 'Vincent Macaigne', 'Louis Garrel', 'Mahaut Adam'], 'title': 'Two Friends', 'year': 2015}
#
# {'cast': ['Hannah Murray', "Josh O'Connor", 'Adrian Rawlins', 'Patricia Potter'], 'title': 'Bridgend', 'year': 2015}
#
# {'cast': ['Kirby Dick', 'Amy Ziering', 'Amy Herdy', 'Annie Clark'], 'title': 'The Hunting Ground', 'year': 2015}
#
# {'title': 'The Ecstasy of Wilko Johnson', 'cast': ['Wilko Johnson', 'Roger Daltrey'], 'year': 2015}
#
# {'title': 'Thank You for Playing', 'year': 2015}
#
# {'cast': ['Ertan Saban', 'Serkan Keskin', 'Luran Ahmeti', 'Funda Eryigit'], 'title': 'Limonata', 'year': 2015}
#
# {'cast': ['Yo-han Byeon', 'Lee Ju-Seung', 'Yoo-ram Bae', 'Jin-soo Byeon'], 'title': 'Socialphobia', 'year': 2014}
#
# {'cast': ['Chaitanya Badve', 'Durgesh Badve-Mahajan', 'Sayali Bandakavathekar', 'Nandita Dhuri'], 'title': 'Elizabeth Ekadashi', 'year': 2014}
#
# {'title': 'Boj za', 'year': 2014}
#
# {'cast': ['Chad Foster', 'Brylyn Wall', 'Martèn Wall'], 'title': 'Western', 'year': 2015}
#
# {'cast': ['Danny Shayler', 'David Sayers', 'Susanne Wuest', 'Edmund Jèger'], 'title': 'The Shaman', 'year': 2015}
#
# {'cast': ['Michaèl Abiteboul', 'Claire Assali', 'Sidse Babett Knudsen', 'Fabrice Luchini'], 'title': 'Courted', 'year': 2015}
#
# {'cast': ['Gabriela Maria Schmeide', 'Justus von Dohnènyi', 'Anke Engelke', 'Ken Duken'], 'title': 'Frau Mèller muss weg!', 'year': 2015}
#
# {'cast': ['Ariel Hsing', 'Michael Hsing', 'Xinhua Jiang', 'Joan Landers'], 'title': 'Top Spin', 'year': 2014}
#
# {'cast': ["Patrick O'Brien", 'Michele Dupree', 'Darin Hallinan', 'Steve Saling'], 'title': 'TransFatty Lives', 'year': 2015}
#
# {'cast': ['Alice Lowe', 'Dolly Wells', 'Tom Cullen', 'Rosa Robson'], 'title': 'Black Mountain Poets', 'year': 2015}
#
# {'cast': ['Laia Costa', 'Frederick Lau', 'Franz Rogowski', 'Burak Yigit'], 'title': 'Victoria', 'year': 2015}
#
# {'cast': ['Benjamin W. Barnes', 'Steve Berg', 'Derek Bevil', 'Timon Birkhofer'], 'title': 'Uncle Kent 2', 'year': 2015}
#
# {'cast': ['Antonia Campbell-Hughes', 'Franèois Damiens', 'Finnegan Oldfield', 'John C. Reilly'], 'title': 'Les cowboys', 'year': 2015}
#
# {'cast': ['Shradha Das', 'Mohan Kapoor', 'Seerat Kapoor', 'Mannara'], 'title': 'Zid', 'year': 2014}
#
# {'cast': ['Aaron Burckhard', 'Chad Channing', 'Don Cobain', 'Jenny Cobain'], 'title': 'Cobain: Montage of Heck', 'year': 2015}
#
# {'title': 'Tanna', 'year': 2015}
#
# {'cast': ['Nikos Dallas', 'Kostas Filippoglou', 'Anna Mascha'], 'title': 'Forever', 'year': 2014}
#
# {'title': 'Tyke Elephant Outlaw', 'year': 2015}
#
# {'title': 'In Transit', 'year': 2015}
#
# {'title': 'The Witch', 'cast': ['Anya Taylor-Joy', 'Ralph Ineson', 'Kate Dickie', 'Harvey Scrimshaw'], 'year': 2015}
#
# {'cast': ['Olivia Grace Applegate', 'Bryan Casserly', 'Alex Dobrenko', 'Chris Doubek'], 'title': 'Krisha', 'year': 2015}
#
# {'cast': ['Scott Swaaley'], 'title': 'Most Likely to Succeed', 'year': 2015}
#
# {'cast': ['Max Casella', 'Trieste Kelly Dunn', 'Jennifer Prediger', 'Onur Tukel'], 'title': 'Applesauce', 'year': 2015}
#
# {'cast': ['Rebecca Avery', 'Amelia Rose Blaire', 'Anna Camp', 'Rosalio Garcia'], 'title': 'Caught', 'year': 2015}
#
# {'cast': ['Kumiko Asè', 'Rirè Furankè', 'Suzu Hirose', 'Haru Kuroki'], 'title': 'The Boy and the Beast', 'year': 2015}
#
# {'cast': ['Malcolm Brickhouse', 'Jarad Dawkins', 'Alec Atkins', 'Alan Sacks'], 'title': 'Breaking a Monster', 'year': 2015}
#
# {'cast': ['Louis Franck', 'Merab Ninidze', 'Viktoria Korotkova', 'Chulpan Khamatova'], 'title': 'Under Electric Clouds', 'year': 2015}
#
# {'cast': ['Jan Bijvoet', 'Antonio Bolivar', 'Nicolès Cancino', 'Brionne Davis'], 'title': 'Embrace of the Serpent', 'year': 2015}
#
# {'cast': ['Marquim do Tropa', 'Dilmar Durèes', 'Gleide Firmino', 'Dj Jamaika'], 'title': 'White Out, Black In', 'year': 2015}
#
# {'cast': ['Christopher Abbott', 'Cynthia Nixon', 'Scott Mescudi', 'Ron Livingston'], 'title': 'James White', 'year': 2015}
#
# {'cast': ['Blixa Bargeld', 'Gudrun Gut', 'Annette Humpe', 'Mark Reeder'], 'title': 'B-Movie: Lust & Sound in West-Berlin 1979-1989', 'year': 2015}
#
# {'cast': ['Max Brebant', 'Roxane Duran', 'Julie-Marie Parmentier', 'Nissim Renard'], 'title': 'Evolution', 'year': 2015}
#
# {'cast': ['Lone Frank'], 'title': 'Genetic Me', 'year': 2014}
#
# {'cast': ['Kirin Kiki', 'Miyoko Asada', 'Etsuko Ichihara', 'Miki Mizuno'], 'title': 'An', 'year': 2015}
#
# {'cast': ['Robert Durst', 'Andrew Jarecki', 'Gary Napoli', 'Debra Kay Anderson'], 'title': 'The Jinx: The Life and Deaths of Robert Durst', 'year': 2015}
#
# {'cast': ['Ching Wan Lau', 'Xiaoming Huang', 'Alex Fong', 'Fiona Sit'], 'title': 'Insanity', 'year': 2014}
#
# {'cast': ['Nadir Saribacak', 'Hakan Karsak', 'Kadir Cermik', 'èzgèr Emre Yildirim'], 'title': 'Ivy', 'year': 2015}
#
# {'cast': ['Aleksey Chadov', 'Merab Ninidze', 'Sergey Makovetskiy', 'Guram Bablishvili'], 'title': 'Ch/B', 'year': 2014}
#
# {'cast': ['Stu Richel'], 'title': 'The Black Panthers: Vanguard of the Revolution', 'year': 2015}
#
# {'cast': ['Lena Dunham', 'Hilary Knight'], 'title': "It's Me, Hilary: The Man Who Drew Eloise", 'year': 2015}
#
# {'cast': ['Larry Kramer'], 'title': 'Larry Kramer in Love and Anger', 'year': 2015}
#
# {'cast': ['Andrzej Chyra', 'Urszula Grabowska', 'Arkadiusz Jakubik', 'Eliza Rycembel'], 'title': 'Carte Blanche', 'year': 2015}
#
# {'cast': ['Ticiana Augusto Lima', 'Guto Parente'], 'title': 'The Mysterious Death of Pèrola', 'year': 2014}
#
# {'cast': ['Josh Rachlis'], 'title': 'Frame by Frame', 'year': 2015}
#
# {'cast': ['Jenny Lampa', 'Lukas Loughran', 'Hanna Sjègren', 'Richard Ulfsèter'], 'title': 'The Break-In', 'year': 2015}
#
# {'cast': ['Dan Aykroyd', 'Alec Baldwin', 'James Belushi', 'Candice Bergen'], 'title': 'Live from New York!', 'year': 2015}
#
# {'cast': ['Janusz Gajos', 'Maja Ostaszewska', 'Justyna Suwala', 'Ewa Dalkowska'], 'title': 'Body', 'year': 2015}
#
# {'cast': ['Jafar Panahi'], 'title': 'Taxi', 'year': 2015}
#
# {'cast': ['Daniel Tadesse', 'Selam Tesfayie'], 'title': 'Crumbs', 'year': 2015}
#
# {'cast': ['Devon Keller', 'Deztiny Gonzales', 'Jocko Sims', 'Kiowa Tucker'], 'title': 'Petting Zoo', 'year': 2015}
#
# {'cast': ['Louis C.K.', 'Jay London'], 'title': 'Louis C.K.: Live at the Comedy Store', 'year': 2015}
#
# {'cast': ['Toni Rakkaen', 'Ingkarat Damrongsakkul', 'Thira Chutikul', 'Arthur Navarat'], 'title': 'How to Win at Checkers (Every Time)', 'year': 2015}
#
# {'title': '(T)ERROR', 'year': 2015}
#
# {'cast': ['Teodor Corban', 'Mihai Comanoiu', 'Toma Cuzin', 'Alexandru Dabija'], 'title': 'Aferim!', 'year': 2015}
#
# {'cast': ['Roberto Farèas', 'Antonia Zegers', 'Alfredo Castro', 'Alejandro Goic'], 'title': 'The Club', 'year': 2015}
#
# {'title': 'The Pearl Button', 'year': 2015}
#
# {'cast': ['Farrah Abraham', 'John Anthony', 'Rachel Bernard', 'Levi Cash'], 'title': 'Hot Girls Wanted', 'year': 2015}
#
# {'cast': ['Natalya Kudryashova', 'Darya Moroz', 'Aleksey Mitin', 'Varya Shablakova'], 'title': 'Pionery-geroi', 'year': 2015}
#
# {'cast': ['Joanne Herring', 'Hamid Karzai', 'Mike Martin'], 'title': 'Adam Curtis: Bitter Lake', 'year': 2015}
#
# {'cast': ['Aaron Yoo', 'Brittany Ishibashi', 'Brandon Soo Hoo', 'Victoria Park'], 'title': 'Everything Before Us', 'year': 2015}
#
# {'cast': ['Antonia Bengoechea', 'Gastèn Cocchiarale', 'Guillermo Francella', 'Stefanèa Koessl'], 'title': 'The Clan', 'year': 2015}
#
# {'title': 'Homeland (Iraq Year Zero)', 'year': 2015}
#
# {'cast': ['Elaine Jin', 'Aaron Kwok', 'Jessie Li', 'Michael Ning'], 'title': 'Port of Call', 'year': 2015}
#
# {'cast': ['Huda Al Imam', 'Ruth Farhi', 'Maya Koren', 'Shady Srour'], 'title': 'Ave Maria', 'year': 2015}
#
# {'cast': ['Jèrèmie Renier', 'Swann Arlaud', 'Marc Robert', 'Kèvin Azaès'], 'title': 'The Wakhan Front', 'year': 2015}
#
# {'cast': ['Mateus Almada', 'Ariel Artur', 'Maurècio Barcellos', 'Irene Brietzke'], 'title': 'Seashore', 'year': 2015}
#
# {'cast': ['Anaès Demoustier', 'Jèrèmie Elkaèm', 'Frèdèric Pierrot', 'Aurèlia Petit'], 'title': 'Marguerite & Julien', 'year': 2015}
#
# {'title': 'Marguerite', 'cast': ['Catherine Frot', 'Andrè Marcon', 'Denis Mpunga', 'Michel Fau'], 'year': 2015}
#
# {'cast': ['Vincent Lindon', 'Karine de Mirbeck', 'Matthieu Schaller', 'Yves Ory'], 'title': 'The Measure of a Man', 'year': 2015}
#
# {'cast': ['Hiam Abbass', 'Maisa Abd Elhadi', 'Manal Awad', 'Raneem Daoud'], 'title': 'Dègradè', 'year': 2015}
#
# {'title': 'Song of Lahore', 'year': 2015}
#
# {'cast': ['Albert Carbè', 'Alba Ribas', 'Bernat Saumell', 'Cristian Valencia'], 'title': 'The Corpse of Anna Fritz', 'year': 2015}
#
# {'cast': ['O.C. Ukeje', 'Nthati Moshesh', 'Kenneth Nkosi', 'Jafta Mamabolo'], 'title': 'Ayanda and the Mechanic', 'year': 2015}
#
# {'cast': ['Claude Lorius', 'Michel Papineschi'], 'title': 'Ice and the Sky', 'year': 2015}
#
# {'cast': ['Aharon Traitel', 'Khalifa Natour', 'Riki Blich', 'Gur Sheinberg'], 'title': 'Tikkun', 'year': 2015}
#
# {'title': 'Tom Swift and His Electric Rifle', 'year': 2015}
#
# {'cast': ['Carly Adams', 'Carl Bailey', 'Thomas Bair', 'Chris Beetem'], 'title': 'Emelie', 'year': 2015}
#
# {'cast': ['Gary Allen', 'Violet Blue', 'James A. Cohen', 'Joseph DeMarco'], 'title': 'Thought Crimes: The Case of the Cannibal Cop', 'year': 2015}
#
# {'cast': ['Toma Cuzin', 'Adrian Purcarescu', 'Corneliu Cozmei', 'Radu Banzaru'], 'title': 'The Treasure', 'year': 2015}
#
# {'cast': ['Margaret Singer', 'Sarah Ellen Stephens'], 'title': 'Hallway', 'year': 2015}
#
# {'cast': ['Atthaphan Poonsawas', 'Oabnithi Wiwattanawarang', 'Djuangjai Hirunsri', 'Panutchai Kittisatima'], 'title': 'The Blue Hour', 'year': 2015}
#
# {'cast': ['Fernando Bolaèos', 'Kattia Gonzèlez'], 'title': 'Viaje', 'year': 2015}
#
# {'cast': ['Clarisse Djuroski', 'Lèa Warny', 'Alain Eloy', 'Myriem Akkhediou'], 'title': 'Les oiseaux de passage', 'year': 2015}
#
# {'title': 'Jeruzalem', 'cast': ['Yael Grobglas', 'Yon Tumarkin', 'Danielle Jadelyn', 'Dibi Ben-Yosef'], 'year': 2015}
#
# {'title': 'Un monstruo de mil cabezas', 'cast': ['Daniel Gimènez Cacho', 'Emilio Echevarrèa', 'Marco Antonio Aguirre', 'Sebastièn Aguirre'], 'year': 2015}
#
# {'cast': ['Micaela Ramazzotti', 'Libero De Rienzo', 'Adriano Giannini', 'Iaia Forte'], 'title': 'Ho ucciso Napoleone', 'year': 2015}
#
# {'cast': ['Gaspar Campuzano', 'Mariana Cordero', 'Natalia de Molina', 'Mercedes Hoyos'], 'title': 'Techo y comida', 'year': 2015}
#
# {'cast': ['Tihana Lazovic', 'Goran Markovic', 'Nives Ivankovic', 'Dado Cosic'], 'title': 'The High Sun', 'year': 2015}
#
# {'cast': ['Matt Cooper'], 'title': "Dennis Rodman's Big Bang in PyongYang", 'year': 2015}
#
# {'cast': ['Charlotte Arnold', 'Steve Coulter', 'Rachel Korine', 'David Maloney'], 'title': 'Men Go to Battle', 'year': 2015}
#
# {'cast': ['Mark Kelley', 'Lisa Allen', 'James Lee Miller'], 'title': 'The Other Side', 'year': 2015}
#
# {'cast': ['Yongzhong Chen', 'Yue Guo', 'Linyan Liu', 'Feiyang Luo'], 'title': 'Kaili Blues', 'year': 2015}
#
# {'cast': ['Ionut Bora', 'Liviu Cheloiu', 'Calin Chirila', 'Teodor Corban'], 'title': 'One Floor Below', 'year': 2015}
#
# {'cast': ['Jeanine Basinger', 'Ingrid Bergman', 'Melinda Kinnaman', 'Pia Lindstrèm'], 'title': 'Ingrid Bergman in Her Own Words', 'year': 2015}
#
# {'cast': ['Richa Chadda', 'Sanjay Mishra', 'Vicky Kaushal', 'Vinit Kumar'], 'title': 'Fly Away Solo', 'year': 2015}
#
# {'cast': ['Sareh Bayat', 'Pejman Bazeghi', 'Navid Mohammadzadeh'], 'title': 'Nahid', 'year': 2015}
#
# {'cast': ['Gordon Peardon'], 'title': 'Manoman', 'year': 2015}
#
# {'cast': ['Alex Cendron', 'Giuseppina Cervizzi', 'Carlo Luca De Ruggieri', 'Alessandro Gassman'], 'title': 'Se Dio vuole', 'year': 2015}
#
# {'cast': ['Feodor Chin', 'Nika Futterman', 'James Hong', 'David S. Jung'], 'title': 'Monkey King: Hero Is Back', 'year': 2015}
#
# {'cast': ['Hye-su Kim', 'Go-eun Kim', 'Park Bo-gum', 'Kyung-pyo Go'], 'title': 'Coin Locker Girl', 'year': 2015}
#
# {'cast': ['John Barrett', 'Andreas M. Antonopoulos', 'Jeffrey A. Tucker', 'Matt Miller'], 'title': 'Bitcoin: The End of Money as We Know It', 'year': 2015}
#
# {'cast': ['Josè Felipe Cèrdenas', 'Haimer Leal', 'Edison Raigosa', 'Hilda Ruiz'], 'title': 'Land and Shade', 'year': 2015}
#
# {'title': 'A Sinner in Mecca', 'year': 2015}
#
# {'title': 'Very Semi-Serious', 'year': 2015}
#
# {'cast': ['Seong-woo Bae', 'Eui-sung Kim', 'Ah-sung Ko', 'Sung Woong Park'], 'title': 'Office', 'year': 2015}
#
# {'cast': ['Loubna Abidar', 'Danny Boushebel', 'Abdellah Didane', 'Sara Elhamdi Elalaoui'], 'title': 'Much Loved', 'year': 2015}
#
# {'cast': ['Christophe Miossec', 'Jean-Marc Barr', 'Jerzy Radziwilowicz'], 'title': 'The Magic Mountain', 'year': 2015}
#
# {'cast': ['Jung-hyun Lee', 'Hae-yeong Lee', 'Young-hwa Seo', 'Lee Jun-Hyuk'], 'title': 'Alice in Earnestland', 'year': 2015}
#
# {'cast': ['Oliver Baumgarten', 'Bernd Begemann', 'Ruth Bickelhaupt', 'Oliver Brècker'], 'title': 'Heil', 'year': 2015}
#
# {'cast': ['Alfredo Castro', 'Luis Silva', 'Jericè Montilla', 'Catherina Cardozo'], 'title': 'Desde allè', 'year': 2015}
#
# {'cast': ['Val Maloku', 'Astrit Kabashi', 'Adriana Matoshi', 'Enver Petrovci'], 'title': 'Babai', 'year': 2015}
#
# {'cast': ['Aleksandr Pal', 'Aleksandr Ilin', 'Kristina Kazinskaya', 'Nodar Dzhanelidze'], 'title': 'Paren s nashego kladbishcha', 'year': 2015}
#
# {'cast': ['Vasiliy Butkevich', 'Pavel Chinaryov', 'Fyodor Lavrov', 'Elena Nesterova'], 'title': 'Tryapichnyy soyuz', 'year': 2015}
#
# {'cast': ['Jae-yeong Jeong', 'Min-hee Kim', 'Yeo-jeong Yoon', 'Ju-bong Gi'], 'title': 'Right Now, Wrong Then', 'year': 2015}
#
# {'cast': ['Hsiao-chuan Chang', 'Qian Wan', 'Tang Sui', 'Yann Yann Yeo'], 'title': 'The Laundryman', 'year': 2015}
#
# {'cast': ['Filip Plawiak', 'Adam Woronowicz', 'Julia Kijowska', 'Malgorzata Foremniak'], 'title': 'The Red Spider', 'year': 2015}
#
# {'cast': ['Maxim Gaudette', 'Karelle Tremblay', 'Valerie Cadieux', 'Mickael Gouin'], 'title': 'Our Loved Ones', 'year': 2015}
#
# {'cast': ['Chantal Akerman'], 'title': 'No Home Movie', 'year': 2015}
#
# {'title': 'Scenes of a Sexual Nature', 'cast': ['Holly Aird', 'Eileen Atkins', 'Hugh Bonneville', 'Tom Hardy'], 'year': 2006}

# %% [markdown]
# ### Nombre y contraseña de cada usuario.

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb+srv://analytics:analytics-password@testcris.whr7f.mongodb.net/test?authSource=admin&replicaSet=atlas-x3zgu3-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')
filter={}
project={
    'name': 1, 
    'password': 1, 
    '_id': 0
}

result = client['sample_mflix']['users'].find(
  filter=filter,
  projection=project
)

for x in result:
    print('')
    print(x)
# Out:
# {'name': 'Ned Stark', 'password': '$2b$12$UREFwsRUoyF0CRqGNK0LzO0HM/jLhgUCNNIJ9RJAqMUQ74crlJ1Vu'}
#
# {'name': 'Robert Baratheon', 'password': '$2b$12$yGqxLG9LZpXA2xVDhuPnSOZd.VURVkz7wgOLY3pnO0s7u2S1ZO32y'}
#
# {'name': 'Jaime Lannister', 'password': '$2b$12$6vz7wiwO.EI5Rilvq1zUc./9480gb1uPtXcahDxIadgyC3PS8XCUK'}
#
# {'name': 'Catelyn Stark', 'password': '$2b$12$fiaTH5Sh1zKNFX2i/FTEreWGjxoJxvmV7XL.qlfqCr8CwOxK.mZWS'}
#
# {'name': 'Cersei Lannister', 'password': '$2b$12$FExjgr7CLhNCa.oUsB9seub8mqcHzkJCFZ8heMc8CeIKOZfeTKP8m'}
#
# {'name': 'Daenerys Targaryen', 'password': '$2b$12$NzpbWHdMytemLtTfFKduHenr2NZ.rvxIKuYM4AWLTFaUShxbJ.G3q'}
#
# {'name': 'Jorah Mormont', 'password': '$2b$12$K8bKkwnpkrjsBPzASZxO/.yj7d9kvupiVtO6JA3Xl106AKXr3pXFK'}
#
# {'name': 'Petyr Baelish', 'password': '$2b$12$qM.YvmiekyYYY7p7phpK3OicbRCDkN7ESwYAnG/o9YnfHC0Mhkmbi'}
#
# {'name': 'Viserys Targaryen', 'password': '$2b$12$cpwVmU4DyuQxgwpdrVJhaudzbKOXlHRbf.tpCuHjpAqonuoyvvEG6'}
#
# {'name': 'Jon Snow', 'password': '$2b$12$fDEu1Ru66tLWAVidMN.b0.929BlfnyqdGuhWMyzfOAf/ATYOyLoY6'}
#
# {'name': 'Sansa Stark', 'password': '$2b$12$nCIVE81..AtAoysPZkl19.G5V0EdIwwsZh1f18lxWEr3dlpG/Uusi'}
#
# {'name': 'Arya Stark', 'password': '$2b$12$19h3KjeTg3/sPNFHztdb6eGWKrCxIwlVXVSh9POSi5PS9kSlguZEq'}
#
# {'name': 'Robb Stark', 'password': '$2b$12$XPLvWQW7tjWc/PX9jMVRnO8w.lR6hv144ee8pc8nDsWIAWxfwxHzy'}
#
# {'name': 'Theon Greyjoy', 'password': '$2b$12$x574mziridS3mEQVTbKbY.lK.ngIDyZJnTw17G7Gk6n4lnWVSrWL.'}
#
# {'name': 'Bran Stark', 'password': '$2b$12$Z7/ztVm8eWMDwTg.doS.UO7JbsbA9IbLomND1VxIZEdAN3keW6csS'}
#
# {'name': 'Joffrey Baratheon', 'password': '$2b$12$fIYLjRg5tZcTcqy30.MJLO4JRblLhsIhFwYTgUpFBbvnf9S4ONbtW'}
#
# {'name': 'Sandor Clegane', 'password': '$2b$12$DKIKOBMbN76vskkRyJ1AjuELigfnx.SeG8vu73k24kfMcO637bSqa'}
#
# {'name': 'Tyrion Lannister', 'password': '$2b$12$xtHwQNXYlQzP2REobUDlzuQimjzBlXrTx1GnwP.xkfULeuuUpRxa2'}
#
# {'name': 'Khal Drogo', 'password': '$2b$12$7tgpVkBxUqQiYFkHjZyoMuEzFU5BSI.FYkOXHu4zCRlRsa15sHQo6'}
#
# {'name': 'Davos Seaworth', 'password': '$2b$12$jbgNoWG97LHNIm4axwXDz.tkFITsmw/aylIY/lZDaJRgnHZjB029e'}
#
# {'name': 'Samwell Tarly', 'password': '$2b$12$ZcZj9wKjlT/dCCrmupiZZ..JA3c9HoufxRygL1DkY9hsClT0iyflG'}
#
# {'name': 'Margaery Tyrell', 'password': '$2b$12$AjC.876rd2dgsSIu.5c4qembdVfdDajMIgueMYuOBoskJUGHzpw46'}
#
# {'name': 'Stannis Baratheon', 'password': '$2b$12$vbPwOM9QkSOsOXRgLSZiqe9JPJtBX1JUwm06d3lYVViKxrYCIyhEm'}
#
# {'name': 'Melisandre', 'password': '$2b$12$ZdSvCDMwVLFgJGDOsDbFLOD/utICnkbJV0OVJJ8lUHqSK3VbuqKuS'}
#
# {'name': 'Jeor Mormont', 'password': '$2b$12$tz5dSvAjtduFuuXFQwMH2OJwb3QKr9/gR5uefaQ3gHJojhLaKxdNK'}
#
# {'name': 'Bronn', 'password': '$2b$12$9rzMIF3lv7kASdTdam2eOOjWrDSN.qi2hpY5tyOfDPe545XfrQHpu'}
#
# {'name': 'Varys', 'password': '$2b$12$mV9NHXHLISu3fDdd6jtU2.6DstBgnC6iWQQR.1h/MsDZp3ftTUBSq'}
#
# {'name': 'Shae', 'password': '$2b$12$FyKikoJynO1kGJ6cTuXaKeKRWauwI5TNlTYiNBgPnizN6XoGB8qpi'}
#
# {'name': 'Tywin Lannister', 'password': '$2b$12$/i04T5yEJvmsBhF0Jd.kJOk3ZhRzezbTU7ASEM5o43Xxsa4o6IgEy'}
#
# {'name': 'Ygritte', 'password': '$2b$12$knwl2v71.oOhFA1W.Yenle8kil56LqhWCOvM7/JVy8E5YrOoZisUi'}
#
# {'name': 'Talisa Maegyr', 'password': '$2b$12$B3DKrkTVNJDlgToXClpcwOJvnKICUsLcrTxNfZIeoqbHIQURsNrXS'}
#
# {'name': 'Gendry', 'password': '$2b$12$ctQymjuvXC5dQXYTWX695eJ/0IEXLfXhNiuzad0bL7j8n9YCBq92K'}
#
# {'name': 'Tormund Giantsbane', 'password': '$2b$12$SsfE7EbmV/HH6nii2jJFOe59P91dAV6CqYdGUDOTkNwcPAScUJyVa'}
#
# {'name': 'Gilly', 'password': '$2b$12$s6/CDf3HFLl3sYNVdOs8sOvdR7HOeQln/ByVQwDGRyTOH5S6qlI7m'}
#
# {'name': 'Brienne of Tarth', 'password': '$2b$12$YjMZPFrj1qS6I/Zy1bxlgOV402ijFcNE.6YVueL5FoWK3eE/QVgKu'}
#
# {'name': 'Ramsay Bolton', 'password': '$2b$12$a5CtSXflNAlkWDVmC70vN.06Zds9s3VlnvSVLNM4quXNkF5spOCsa'}
#
# {'name': 'Ellaria Sand', 'password': '$2b$12$/sfLmn9AwehR9itBml.p..fKYxUv66om0TallTLMjw2klrmiLwaHy'}
#
# {'name': 'Daario Naharis', 'password': '$2b$12$22Oqs3Wq.ObJ3Vr68TJKteCSEV1JWIt8jM7/3lf21vOA.jQkdHoBq'}
#
# {'name': 'Missandei', 'password': '$2b$12$wMY9mXJCiDZ5dPbgroygBOKjWbuCzv.Snb1sZlp7v41LzyueP/G.S'}
#
# {'name': "Jaqen H'ghar", 'password': '$2b$12$sgxhWIzY6UiWvWFRMslCDusielBdf8tpNHraxHAS3c9QNwcCHdHJq'}
#
# {'name': 'Tommen Baratheon', 'password': '$2b$12$POxM5GGAYJNe2phLqcZJ5.3MXEVhUXTQouqvc3hwCU1ZItYbySQsy'}
#
# {'name': 'Roose Bolton', 'password': '$2b$12$JWXzYGip0vvuT40B23mZB.KKoHocgoW2FshxzmhDstZqR23vEtZpS'}
#
# {'name': 'The High Sparrow', 'password': '$2b$12$wWkC3fCEuI5X1WoXJft0hOu2qm95MKVmI996/68kXBRUn0HXHebHC'}
#
# {'name': 'Grand Maester Pycelle', 'password': '$2b$12$R2KQQQMmjcrbm5XgGdkFJ.38e0I7KptV479H2p1UJ2t5TTb3OSww6'}
#
# {'name': 'Meryn Trant', 'password': '$2b$12$rB95MlNcAdrflKD1gUdiTOg55dbPUtH6po4kKMHGxQjbU9L4k0LBu'}
#
# {'name': 'Hodor', 'password': '$2b$12$hFkSycBpMDENs/sT.5y0feifE5IluHUJmYHqH/lSkcc81/HRzzRSq'}
#
# {'name': 'Grenn', 'password': '$2b$12$gpgDQ2RBHotU4x/ppd0P9ueseDdLTzFHB.4kjkez/ZNerubyFSy1i'}
#
# {'name': 'Osha', 'password': '$2b$12$NpElja7NerH/Vz.6pN0vV.7PNo1fOvMgFx0O8VOro6idM4Evn7n4G'}
#
# {'name': 'Rickon Stark', 'password': '$2b$12$LKBf/wrMe29RwjUCkm6sq.AfuAXshbX6Evys3twd9vaGEsEm6YBqC'}
#
# {'name': 'Ros', 'password': '$2b$12$dpUAAVPghWXEu0pg0Kv9rOP9bZexMblG911BJzJD/2HOuMat6ZsOe'}
#
# {'name': 'Gregor Clegane', 'password': '$2b$12$6NQKRPtpvs.3w2VuLBgQv.nYBplKlGVK3GRvLqw1n06wO424E.zq6'}
#
# {'name': 'Janos Slynt', 'password': '$2b$12$ssMaPHBLj9tGpLgRXWSCeODrtccHwVbZvDKckjSg1duBLsBZOco8e'}
#
# {'name': 'Lancel Lannister', 'password': '$2b$12$mNWiHoOqOWQser3s6ezqZeTU5vhskTq.K7xkeTA2P.CIfoWsHvonO'}
#
# {'name': 'Myrcella Baratheon', 'password': '$2b$12$boJbPqaRG45hQs7jzcwLWu03lGXG9DHIn3rVHcJQ/NK0PaYokP5eu'}
#
# {'name': 'Rodrik Cassel', 'password': '$2b$12$dIvO2KpkHkje98eMZg.exuDR.MeOkHlRC9R7PTKj1D66PhX4NaDP6'}
#
# {'name': 'Maester Luwin', 'password': '$2b$12$K9m5hh0Lh.NtYqRpxF40NeWTRwOM7nPp4NJL5v/9fZZ/vpIWKN3KO'}
#
# {'name': 'Irri', 'password': '$2b$12$mTvd3eFqgflqO74rS95zKOFU3wKRe5alg.iM23AknNnpZ/TdT95eK'}
#
# {'name': 'Doreah', 'password': '$2b$12$3M34QX9A/7jNLn9neSddUeW5oJfcl5OYOqYUL.7L87/ThA8Xbfug6'}
#
# {'name': 'Kevan Lannister', 'password': '$2b$12$YB/GLht749jn9jxcwOnw4.ZekNoiSzmS8qS.raqFzZPrNbBJAB20O'}
#
# {'name': 'Barristan Selmy', 'password': '$2b$12$IabcnI3C6lUTfq2Ez5f0bOEsM6Hok6JsPMyTxnVHwZGIEaHtpohsy'}
#
# {'name': 'Rast', 'password': '$2b$12$wzKOV4fkmI5hfiQLFYpSDePsSBqenWs8CpI1N7OcD1A.3NF98adqy'}
#
# {'name': 'Maester Aemon', 'password': '$2b$12$uOefAK8L28vlzZ9lsZV2Q.LplAND.FPwKHPmZ7wgXeO/F0mbVR1b2'}
#
# {'name': 'Pypar', 'password': '$2b$12$GTKOrQ2gHc1o0OE37ub6d.yKxI4o9RU/72kPAbiaUbqkrANKYO34W'}
#
# {'name': 'Alliser Thorne', 'password': '$2b$12$IWJV4xTZ4dyBsvwQQ2FlF.yw3Mfy.XZCOsprt6kaLRtHu9k6ZHbx.'}
#
# {'name': 'Othell Yarwyck', 'password': '$2b$12$RfLlYF.8Vxj4MXILL2kvIuyuAO8rN3KR6//UL1a6rNIfNgBaASS66'}
#
# {'name': 'Loras Tyrell', 'password': '$2b$12$Eb5TLqYLS74pLP9r.2agNe56ht1dvFkQOCODxku8KQmLfldBGa7Cu'}
#
# {'name': 'Hot Pie', 'password': '$2b$12$o99XQuQRvutjESJ8/eqnWe4w8aCYXHFF1cJmZdeKs6acmoPaVlCK.'}
#
# {'name': 'Beric Dondarrion', 'password': '$2b$12$CHeWRV3bBssK0MR1o4FLcOCmFLaPIPTA0KzKI0aWYDnXCKm98MbJy'}
#
# {'name': 'Podrick Payne', 'password': '$2b$12$yYDEeKYMkE2zDjP35/RfZONzFZEuv026MnSRAJ5ZPUoBUhvu6ZRN.'}
#
# {'name': 'Eddison Tollett', 'password': '$2b$12$adD4J5Cnk/aeVdKC3qnD7ufw7S9sTrvWoiSxNkLqZsr0SWjFj91Wq'}
#
# {'name': 'Yara Greyjoy', 'password': '$2b$12$q4rJ2PG4ZJZ1c9PNJeZU1uHH/ckwCh4P0xfu6lGgHIQ8/ugptuQuK'}
#
# {'name': 'Selyse Baratheon', 'password': '$2b$12$Ri/w5TEI/CsWxvdscYkzhuVzKF0Zy98zgDWO5pmVsXb05jki5PKrG'}
#
# {'name': 'Grey Worm', 'password': '$2b$12$Kplgm66WrJlrIxV7g.uQj.zSSY3Q/GuznI6i9z5I9abqcszpTGc0O'}
#
# {'name': 'Qyburn', 'password': '$2b$12$Aogz..TkpBMB5UFfgIRSP.dy7DX9qgOi587FSORqRWqApfbw3x7wy'}
#
# {'name': 'Olenna Tyrell', 'password': '$2b$12$8Oh3DVnn8e5NK9nHtX4ZVeprB3O6Zrb8l8KxT2l3rraW11HhxH3di'}
#
# {'name': 'Shireen Baratheon', 'password': '$2b$12$F8VweX6dNiq4Gymmc7LJsu5U1G0d0wxaf/95CVl5w/4..mFfdgqdG'}
#
# {'name': 'Meera Reed', 'password': '$2b$12$SdyXPBMdGScx6DePpPawFeOqcpiwjdHAuTXaPl0mkvWeLzZk6EWTi'}
#
# {'name': 'Jojen Reed', 'password': '$2b$12$ZAJ8OFWUFNdxhc0xyTd42evQJfL7FnEdk3koHwYtHpDqsrZI61XP.'}
#
# {'name': 'Thoros of Myr', 'password': '$2b$12$bkA1MM3UEwZ4N0VpCQY68eMY8HKTHWtk2xI2QnG4MuW5UWHlBrF8G'}
#
# {'name': 'Olly', 'password': '$2b$12$Mp0mG3u/6xuQSe/3/UjO8uHTHUDQUIcV0Iki42vfAqKLaBbYxHjv.'}
#
# {'name': 'Mace Tyrell', 'password': '$2b$12$Z7BRen4BsJqxnBlsRupWou2DlT7CQameOt7V9UlV0vWw3Z2B9sDj6'}
#
# {'name': 'The Waif', 'password': '$2b$12$JGlWYUPkZ3xryO9h4x4wdOsnbuLdzbSMSCaJENY6LaLfWYIl86xdG'}
#
# {'name': 'Bowen Marsh', 'password': '$2b$12$G8bl4haz.de9f1ohneIcIus3GCj4nNNP7WiufQy6.aoIh01AVk2Xq'}
#
# {'name': 'Richard Davis', 'password': '$2b$12$q5/117rbpGoczEDK5LcDjeeOmOnzkVi6h2VIN.1Dbugn6Y5kOo4Ja'}
#
# {'name': 'Greg Powell', 'password': '$2b$12$XpveUB6kIiU3zG5aABw26OitIB7cDBbSUWJAz4WDF4XXyNNJ/mp76'}
#
# {'name': 'Sarah Lewis', 'password': '$2b$12$5kCUjcP3lvYSzhouVJTpOeCZ7e7Xke8gDoPPg2Uyz39tNKrp9om1a'}
#
# {'name': 'Ronald Cox', 'password': '$2b$12$HhDeE1teAaNqj2Mrfn4f2O57K8z6kVVqtCEr.7Qc5BZR69H6XwRlK'}
#
# {'name': 'Emily Ellis', 'password': '$2b$12$UuCb5RqPEgheoLlwOF/Jb.x9gpFVmD30oUwpSRKljwo8pBUmWT6eG'}
#
# {'name': 'Victor Patel', 'password': '$2b$12$VyWh4xdBtuZrhuR933GY6evfU7.py2dJIP9wuSmeiJ.94iP0EO4Pq'}
#
# {'name': 'Karina Martin', 'password': '$2b$12$s6XOIsF9p9/p6tZd0nZ1ee5qd6/nc5sL8dd0iES0ZEJySgacjcqD.'}
#
# {'name': 'Robert Jordan', 'password': '$2b$12$OumeM9/x5dBn5RLd/5QUNu8poyzsVbhJtLs2S02JqCwzubbbBK902'}
#
# {'name': 'Javier Smith', 'password': '$2b$12$ce2znqUW43.BjKQaTS5tiekhqZuCLQHOguozLkVm4P.WM8VlrEhPe'}
#
# {'name': 'Amy Phillips', 'password': '$2b$12$z.IU36O/1r25xdhI.Gdw1e2dLXSjIgIMNrxginP0/iVIlZcCWiyaK'}
#
# {'name': 'Jason Smith', 'password': '$2b$12$l2JMT18BcA8.R3tUxVDKj.9/jwre8CAccr21PvJ576nJ8Pvegxn0m'}
#
# {'name': 'Cameron Duran', 'password': '$2b$12$50w2j63ATGmhVOh2rgdjv.wOd9TV0Jb9Xk/Anms0fxVSvGMf5MwvK'}
#
# {'name': 'Megan Turner', 'password': '$2b$12$nR8x.s7PmEQttaF7RS33euSLEZzuu0G2UhSK.PeHJEZEjcK.J3Xq6'}
#
# {'name': 'Megan Richards', 'password': '$2b$12$iDxjjcgBA.Q9zjTlOD4KJuhPJx6gw5GecbDWCbVmfzzv2rqNbC2vC'}
#
# {'name': 'Thomas Buckley', 'password': '$2b$12$.zRRXpjiT0uuR13kt85CDesUMJPIEK1mziudzedd7S10YVAd31586'}
#
# {'name': 'Lisa Rasmussen', 'password': '$2b$12$HHK6sMwGNXZlOHOpFXcHpuS3qS8/XA2202y7ZIlTJ.6y5E6SUl7Yy'}
#
# {'name': 'Connie Johnson', 'password': '$2b$12$tA3NXW5mHAru7YbIrW6x3.T3OweDVjBwk6wf/ukXBiwxAZXi3R5m2'}
#
# {'name': 'Victor Fleming', 'password': '$2b$12$DQSGcwfMllp0HTDNI6QLGeI41zrqprdlEnIXf6RHdpOCMBc37wzV.'}
#
# {'name': 'Brandon Hardy', 'password': '$2b$12$7qxHDP2xlgztpQITlwjlBugE2ned0nRmm22Gu1mK34fZJvh5IE4SO'}
#
# {'name': 'Kathryn Sosa', 'password': '$2b$12$naMKKiQlGxdNh1WMCa6ws.Yo1nEr5OWBILzMYEDlt.fw.UmOVnMhu'}
#
# {'name': 'Mrs. Ariana Nunez', 'password': '$2b$12$KN9tlEa1K65zgHHG7zh2KePPpU0/NC1o/WN3RoIOaHBvWEoPq2DMC'}
#
# {'name': 'Yvette Roth', 'password': '$2b$12$JmceK9VLl7aY/uF9.ZdLTOuj0y5xR3jjvDZVyFCCPQT/lly5IocIm'}
#
# {'name': 'Kelsey Smith', 'password': '$2b$12$S.moHRDfHWLM.F5IasBPQek/y76l0ejX.a5EnPQMbtpECI3tWXS/y'}
#
# {'name': 'Keith Phillips', 'password': '$2b$12$oXW3cr3lIY37/Ps3uSZBj.rFQoFjZAuFvtHNyxHyocIIlI9lT93MO'}
#
# {'name': 'Morgan Smith', 'password': '$2b$12$vm836TjgawCzAglcRq/GWOPJpAOT9W.w0tEAGqoIvDxMRn.rfZCQK'}
#
# {'name': 'Anthony Thompson', 'password': '$2b$12$Ki.7nartO8MscZ53cV5jEuLa83JD8OKd6sgCqxird98ijmWRTRcrC'}
#
# {'name': 'Joshua Kent', 'password': '$2b$12$xSofV4dlicgiRA9yRtB9BescTvQFusNdde7/yz6AQ8lRKKMTdhRLW'}
#
# {'name': 'Brenda Martin', 'password': '$2b$12$H.QWgwnd5SwchVniifWfS.BmBefv6FhBBKqjcDlI20ZdqgFvIy3F2'}
#
# {'name': 'Garrett Obrien', 'password': '$2b$12$ElY14tB9rHL3L4yhrY7gcOGr0u0eFZ5Eb6IoG3eH15sqAeAqbco/a'}
#
# {'name': 'Lori Franklin', 'password': '$2b$12$h25/G5rXZejwsAhn7rvYIuuLzwnayZcf4yX0CV02gDh0dA14UyVsy'}
#
# {'name': 'Kenneth Chandler', 'password': '$2b$12$Bo8ObYfsGdSsJrcdf/bat.NFhp4ITDrsyZvYlTmZWh.zrReVKVH4u'}
#
# {'name': 'Daniel Simmons', 'password': '$2b$12$o2vaieyGbqZ5a.BhIB3e9.cZ1dEO3Ob/3gc1Ef1/QX4cI9vnMraUC'}
#
# {'name': 'Paula Sullivan', 'password': '$2b$12$6eM.dlL7Wi84eYUkwzkU.erG/JqAvwOKSGn5V1bG6HLfIFrpTYaXi'}
#
# {'name': 'Richard Schmidt', 'password': '$2b$12$3odZLmzPAoFZc/S3mVRCWOimTOx.RGTY1CP/jJBsW42F0zfbwOXQK'}
#
# {'name': 'Anthony Smith', 'password': '$2b$12$OLhPk6TMdQ9rY/LIMjsaa.Pfb6IlCQgZK2BCx37lYqotgy9tHo3F6'}
#
# {'name': 'Michael Day', 'password': '$2b$12$1BdlPh4Imkw8kn7aCgEWsOCt1DED7cFTMlVOf62k6lGxEvQEe1L56'}
#
# {'name': 'Mercedes Tyler', 'password': '$2b$12$ONDwIwR9NKF1Tp5GjGI12e8OFMxPELoFrk4x4Q3riJGWY6jl/UZAa'}
#
# {'name': 'Kristen Schmidt', 'password': '$2b$12$lUexqpKoc6RNXLAHGPZ50OLWr3oKfrJW9Vg.q6s7DrCs5X0blJYtW'}
#
# {'name': 'Justin Williams', 'password': '$2b$12$5GAeUijkM4g3s5yBZniXxOYlA13vLLt.CPkXLCs3jlfsYJrgJ37fy'}
#
# {'name': 'John Roman', 'password': '$2b$12$UW2RqzQlgLcPNLn3gxY16uMhqso5GgeAzYfAQVY2yplhacxZ.daSy'}
#
# {'name': 'April Cole', 'password': '$2b$12$DhQx.0ywiZK7v4UrN6YeXuS06U2JHNM2owUHxbL8aXlobGT7E65Ke'}
#
# {'name': 'Kimberly Gates', 'password': '$2b$12$fE/FzdNHaDJS2nW5jPziHe0lgKcVqPEF6B2X7vCx35RgvEVp2DS7y'}
#
# {'name': 'Denise Davidson', 'password': '$2b$12$kjWPMnQwGlwe7NGI0NdE9uq3KGvJ8jA0bJILkEUXFE9tzPVjwzJ1a'}
#
# {'name': 'Michael Moore', 'password': '$2b$12$9rCFOeptsZ6eFBzoprKRFOKS.NQteHtfWurzBkndHNt9DLVdAZGsW'}
#
# {'name': 'Lisa Silva', 'password': '$2b$12$K8ZpLpGQUUFev/fxmJSlueIdVJ3.7CNYRNERCRae5B1auB7SLBTu2'}
#
# {'name': 'Andrea Le', 'password': '$2b$12$JS87HWuL2y0P1E6kYrcbKOKx22.wsKEdLtS0F734/vKdhuduLM8Ve'}
#
# {'name': 'Edward Barrett', 'password': '$2b$12$Jzx8f0IiHYFcdU/PEceFJeS1HjC43HTL2aBhKQt8uUM2zfJf3p7Ki'}
#
# {'name': 'Christian Williams', 'password': '$2b$12$D2/B/KGdHRduXiT0/OX5Yu0YMfubTWOOaCjuOyQrDUMvq2Eju10ny'}
#
# {'name': 'Jason Hernandez', 'password': '$2b$12$fmvh3F8TRhntCXSCTb/oG.MJlZmXwStdf/UfCSFnSxSsbJb0Bsmwi'}
#
# {'name': 'Patricia Good', 'password': '$2b$12$t9xIBFolWLphJBO9VCpV4uoZDx/TOhg7N436kBe72hgDMxsGvQr3m'}
#
# {'name': 'Barbara Gonzalez', 'password': '$2b$12$qxLcDfjy7RdjfJbrFRHntu0kzVnXzJKED0on8TZ84dLlSCKKkaJt2'}
#
# {'name': 'Denise Bryant', 'password': '$2b$12$Dcm7ncpCt0PVR4HFux4hDetCNL3E3mQg9GKqJHR/Nz/O40HCgEJzu'}
#
# {'name': 'Victoria Sanders', 'password': '$2b$12$/2aikvro4gXgcp01Z8qIj.s2s53lpVcLQRbG/9VNbHa4i3ajo5dc.'}
#
# {'name': 'Taylor Scott', 'password': '$2b$12$rIJO4MKGZFHKyPeU9X8hSOsCjL3Isa9Gv8rZ7rzM7kKA3XUd1PAlO'}
#
# {'name': 'Taylor Hill', 'password': '$2b$12$5NRO3TpZti62ZN2rSlxYoOurfMQAUEQ4oIufrfAhcsSqGp4eKF4Gi'}
#
# {'name': 'Melissa Jones', 'password': '$2b$12$S6.mFqBn8QMRtyeJUJbRcOwkrgtjHyg7GkmxilnWvOzRtPar.d1K.'}
#
# {'name': 'Christopher Robinson', 'password': '$2b$12$Bop6XQ2mLRjsMXPjKUEtcuIw9751lV.cKj/eXM1ZwSetsku3sa04W'}
#
# {'name': 'Amy Ramirez', 'password': '$2b$12$LN9OzMA5sX3bQnMjkkWa.OjMrjif.LIbqx7YSf52FtQ9QcBlUS8ee'}
#
# {'name': 'Phillip Collins', 'password': '$2b$12$3XQmnWfaMh9bwJMXAdJLheLLiU7bCVATlDsdo4BREnIQFbfCxUOcK'}
#
# {'name': 'Jerry Cabrera', 'password': '$2b$12$HEimsC0UBidI9AYqPU4Mr.P8UZVO6zsZm2VUFVeuA467fdqp8WJDu'}
#
# {'name': 'Ms. Cathy Miller', 'password': '$2b$12$wQ02A.LLpeLLEItcBZF2IOOSlds3VjdaXOI2XRt/ElyG2852ITbiW'}
#
# {'name': 'Lisa Russo', 'password': '$2b$12$pOdj440b9rps82eCfXzCiONHjBo9zowp62kNDdQSRVPMwGJmxAk0W'}
#
# {'name': 'Thomas Morris', 'password': '$2b$12$IfMqv/fVHb3KZtQxKtUXP.C.Uh9rNI9qKWB4eZ6d2YiEl5P3XnDk.'}
#
# {'name': 'Elizabeth Wiggins', 'password': '$2b$12$UGbyi1WBFHu9xqTYp2nxzuGtWaolgxyj/7r2kXjSltr7s8jzr8RFm'}
#
# {'name': 'Nicholas Webster', 'password': '$2b$12$LLuOi5eMoy6hWIC61dolKu9/0bxRKsL0kwWfcJ8A0qr.SX/AR5aCi'}
#
# {'name': 'Teresa Thomas', 'password': '$2b$12$vQQlmv3ubYNZh8HfSXmu4.peazChIJo15UEnLpQz9O90nr8U/qlfS'}
#
# {'name': 'Catherine Romero', 'password': '$2b$12$XVWuCkFmEypxLhpe6OnZdeZ2HcO/mD.q0bcDun5izEPMDCSTGW5AO'}
#
# {'name': 'Julia Nichols', 'password': '$2b$12$HZbkbktkRTaV7LiwLxW3D.gDV5lQAy05Wumz981D7gwvSoAc9uJxq'}
#
# {'name': 'Heather Leonard', 'password': '$2b$12$/mzEsE5kIBX1sWGWlp4GuOilNW.h5ZSIWVgYh.kbt3i0LG3BPY3hy'}
#
# {'name': 'Melissa Young', 'password': '$2b$12$iei9pWuCZ6wF/TJhVJ1gE.k7dkc.0NiHgR6/lJCn4ANkaBkdKS/Wy'}
#
# {'name': 'John Rice', 'password': '$2b$12$Yg0bT/yCT5fX8xn.D4Fj3.slpd7tccYWKgRGghrLglX5Faz6Fb86G'}
#
# {'name': 'Blake Sellers', 'password': '$2b$12$g2u20yqqpzbNipA6lfIoBO3Cs9jM7jsWBhDheF1OsthHpLfEcD2Gm'}
#
# {'name': 'Theresa Holmes', 'password': '$2b$12$1b.0k6/Ox.r9CHmPYPIs2eH5FZolXLc5e9E4IyTJd3YkzAVTB1Dta'}
#
# {'name': 'Bradley Brooks', 'password': '$2b$12$YvZMPevRPXozhmujYwhFe.oTEHhdvHrJEviyXaXUjLsDr6tkHBoC.'}
#
# {'name': 'Thomas Green', 'password': '$2b$12$6u6dECDnaDoNehg1gU14KOcGAtmMnKcnsSv7U2W693xk/UTKF.of6'}
#
# {'name': 'Jonathon Mccullough', 'password': '$2b$12$uZlaQmlnL501KsvPJSCJbO47tz9.8GB8Hl0Xu31xURToXMP8dWzOi'}
#
# {'name': 'Jeffrey Roberts', 'password': '$2b$12$UrTFJ6Xnr043.QRwFVlqgudHC6GPSjejaldJw2/UFsR.dyPwj7cxK'}
#
# {'name': 'Jose Hall', 'password': '$2b$12$ghmMMtvS1Wcmf9.UEF5ep.sAU5KS2.GUpgK41hiPh4EzyJYCy2P42'}
#
# {'name': 'Jennifer Frazier', 'password': '$2b$12$Xm1ktF5woIqEw5q00xCnZO.PwJDWi9VIrbbrMemqv5zzF1zJGN2AC'}
#
# {'name': 'Jamie Santana', 'password': '$2b$12$KhXBuPIzyxoqMjpTn4h4ku9Dky3bofFDVNrMD5T6Z2Dd1j1wWAGe2'}
#
# {'name': 'Anthony Cline', 'password': '$2b$12$JWTRRBJgXOv.peG2HDFHeORuwvOaZigFtxhUSDhbpPEFRRuhS19F2'}
#
# {'name': 'Donna Russell', 'password': '$2b$12$5PICbqGRxD2Mj5ljv0wQnu6d.a4mNPoma1GtMvYOHE.M7bz6vIu4e'}
#
# {'name': 'Blake Fitzgerald', 'password': '$2b$12$.ilQEC/iyR4FhnMA1PmzVe.kMkAbI7htSZJKquTjnaVFH.RDmsP32'}
#
# {'name': 'Mary Mitchell', 'password': '$2b$12$rT8TmryDDeU446M.g1vVCePtByl85Y/vZ/awAn3eOXCke.bKXHr9G'}
#
# {'name': 'Deborah Kennedy', 'password': '$2b$12$lJL2fO48ZrLRhZTf1FBVv.eaaQQ6FSSUh/SwAqvRkcCgM1lZp4moG'}
#
# {'name': 'Lori Blankenship', 'password': '$2b$12$SQUa.3cIKcazfuUOpd9/huR.VeFAH.uR.ESvIMfbMW1YQjZx47Tw6'}
#
# {'name': 'Paul Bailey', 'password': '$2b$12$m4x95MQ5iSqH.SmcxmBeOuiDYUi9iMcjT1VHXiwKBPHtQ9MNrKnru'}
#
# {'name': 'John Bishop', 'password': '$2b$12$ifnm6ZFlRQaV4YFe2WcpKuyYfp2eW.42QECH7dkEoD0WeTFpQ8pCe'}
#
# {'name': 'Nichole Miller', 'password': '$2b$12$RwG1XZMs3MT/kfdH0L2EWOrfUkOuDkMl./KT.xld4Wyie9w87CM1a'}
#
# {'name': 'Yolanda Owen', 'password': '$2b$12$lmpyYO8lCI.Y/J5AZF6/4u8XyEnCoZXsZzf7l9f7ECNbktqH2KZO.'}
#
# {'name': 'Nicholas Johnson', 'password': '$2b$12$hdzNySj4l/tZR4op5oQXb.FStH3u7ZHjmhhtrpQFIEe39NkBS6R1y'}
#
# {'name': 'Desiree Pierce', 'password': '$2b$12$6ndntifLUo9dshFeTkyOEO.xskWXa1n2q5dcl9uOglKz3cd0vMeJm'}
#
# {'name': 'Connie Barton', 'password': '$2b$12$dFHzE0VmGHX7K7Je4QWZ0ucv4XX7zup9FWvrF8NFUHlm4k2a4z2se'}
#
# {'name': 'Patrick Knight', 'password': '$2b$12$GrKhwH1qeeJNGcGLmjg9f.k7ruCRxGUbfm4z3mgzGkiXXZVvKGCwy'}
#
# {'name': 'Eric Navarro', 'password': '$2b$12$ULJ9tL7jh8yPXNDmCJi4C.mzkxzLfIQXakq3td9dJQs3io/Zg/AE2'}
#
# {'name': 'Jordan Medina', 'password': '$2b$12$QcSxfXU.jBizvmaU/zc33eIChz4lVAcQalzCupFBv3eGYEsVhJazW'}
#
# {'name': 'Donna Smith', 'password': '$2b$12$LYIyq5Bsszh3/8efEYmJRuWDqhOeg8K5czQwSLxEBhOTyhOX34JEy'}
#
# {'name': 'Shawn Mccormick', 'password': '$2b$12$fVJEFj7SXlqT0EmE9k00FuZLNH52NFSPriUqm8GGT6QQmuzrsMwUC'}
#
# {'name': 'Anthony Hurst', 'password': '$2b$12$9M2cew6pOM.35LY474rMkeVD4WxfvF2lDtVg60jZrlMdbaexrIfwK'}
#
# {'name': 'Ashlee Hart', 'password': '$2b$12$S707opDk6HG/Lqk7MaHeQ.1N36I6kEUOhRv/RQEHZUbw89xAuO6Ju'}
#
# {'name': 'Magical Mr. Mistoffelees', 'password': 'somehashedpw'}
#
# {'name': 'foo', 'password': 'foobar'}
